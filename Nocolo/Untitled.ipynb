# %%
import pandas as pd

# %%
df = pd.read_csv('D:\OneDrive - NITT\Custom_Download\sample_dist.csv')

# %%
def get_embedding(x):
    return [eval(i) for i in x[1:-1].split()]

# %%
df['Embeddings'] = df['Embeddings'].apply(get_embedding)

# %%
df
# Out:
#    Unnamed: 0.1  Unnamed: 0              text  intent             arg  \
# 0             0           0         Kids show  BROWSE    content_type
# 1             1           1         Kids show  BROWSE  genre_modifier
# 2             2           2  The Grinch movie  BROWSE    content_type
# 3             3           3  The Grinch movie  BROWSE           topic
# 4             4           4         Cat movie  BROWSE    content_type
#
#           enType       value  \
# 0  type_modifier        show
# 1          genre        Kids
# 2  type_modifier       movie
# 3            NaN  The Grinch
# 4  type_modifier       movie
#
#                                           Embeddings
# 0  [0.5989784, -1.08036363, 2.19890046, 0.9927322...
# 1  [0.5989784, -1.08036363, 2.19890046, 0.9927322...
# 2  [0.377731681, 0.310285628, 1.32053411, 0.20112...
# 3  [0.377731681, 0.310285628, 1.32053411, 0.20112...
# 4  [0.248197719, -0.0870495141, 1.40386951, -0.29...

# %%
df.to_json('filename.json')

# %%
pd.read_json('filename.json')
# Out:
#    Unnamed: 0.1  Unnamed: 0              text  intent             arg  \
# 0             0           0         Kids show  BROWSE    content_type
# 1             1           1         Kids show  BROWSE  genre_modifier
# 2             2           2  The Grinch movie  BROWSE    content_type
# 3             3           3  The Grinch movie  BROWSE           topic
# 4             4           4         Cat movie  BROWSE    content_type
#
#           enType       value  \
# 0  type_modifier        show
# 1          genre        Kids
# 2  type_modifier       movie
# 3           None  The Grinch
# 4  type_modifier       movie
#
#                                           Embeddings
# 0  [0.5989784, -1.08036363, 2.19890046, 0.9927322...
# 1  [0.5989784, -1.08036363, 2.19890046, 0.9927322...
# 2  [0.37773168100000004, 0.31028562800000004, 1.3...
# 3  [0.37773168100000004, 0.31028562800000004, 1.3...
# 4  [0.248197719, -0.0870495141, 1.40386951, -0.29...

# %%
if pred.strip() == 'non-canonical':
    pred = 'Canonical'
else:
pred = 'Non Canonical'
