# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Getting Data

# %%
import requests

# %% [markdown]
# The get_data() function retrieves movie data from The Movie Database API by sending a GET request with a specified URL and headers. The input is an IMDb ID, and the output is a response object containing the movie data. The function also supports retrieving data by movie ID using an optional flag parameter. If an error occurs, the function prints an error message.

# %%
# sometimes websites stop you from extracting the data for some reason. It can be due to some authentication errors.

def get_data(ex_id,flag=False):
    needed_headers = {'User-Agent': "Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36"}

#     url = "https://api.themoviedb.org/3/movie/popular?api_key=81b49b634e27bb42bfe9fd2a462146c0&page=1"
    if flag:
        url = f"https://api.themoviedb.org/3/movie/{ex_id}?api_key=81b49b634e27bb42bfe9fd2a462146c0"
    else:
        url = f"https://api.themoviedb.org/3/find/{ex_id}?api_key=81b49b634e27bb42bfe9fd2a462146c0&language=en-US&external_source=imdb_id"
    response = requests.get(url, headers = needed_headers)
    if response.status_code !=200:
        print('Error',ex_id)
    return response

# %% [markdown]
# The get_json() function retrieves movie data from The Movie Database API using the get_data() function and an IMDb ID as input. The function then extracts the movie ID from the response object and sends a second GET request to the API using the get_data() function. The output of the function is a dictionary object containing the movie data, or an empty dictionary if an error occurs.

# %%
def get_json(imdb_id):
    response = get_data(imdb_id)
    try:
        api_id = response.json()['movie_results'][0]['id']
        response = get_data(api_id,True)
        data = response.json()
        if data['revenue']!=0:
            return data
        else:
            return {}
    except:
        return {}

# %%
# data = get_json('tt6359806')

# %%
import pandas as pd

# %%
# Uploading the csv file in order to get the ids  
df = pd.read_csv(r'titles.csv.zip')

# %%
# Store IDs
df['imdb_id'].dropna()
# Out:
# 1        tt0075314
# 2        tt0068473
# 3        tt0071853
# 4        tt0061578
# 5        tt0063929
#            ...
# 5843    tt14216488
# 5845    tt13857480
# 5846    tt11803618
# 5847    tt14585902
# 5849    tt13711094
# Name: imdb_id, Length: 5447, dtype: object

# %%
# Remove rows with missing IMDb IDs

df = df[~df['imdb_id'].isna()]

# %%
# Check that these are the IDs
df['imdb_id']
# Out:
# 1        tt0075314
# 2        tt0068473
# 3        tt0071853
# 4        tt0061578
# 5        tt0063929
#            ...
# 5843    tt14216488
# 5845    tt13857480
# 5846    tt11803618
# 5847    tt14585902
# 5849    tt13711094
# Name: imdb_id, Length: 5447, dtype: object

# %%
# Retrieve movie data from The Movie Database API for each IMDb ID in the
# DataFrame using a progress_apply() function. Store the resulting JSON data
# in a Series called json_str.
json_str = df['imdb_id'].progress_apply(lambda imdb_id:get_json(imdb_id))
# Out:
#   0%|          | 0/5447 [00:00<?, ?it/s]

# %%
# Convert the Series to a list of dictionaries
data = json_str.tolist()

# %%
# Normalize the data into a Pandas DataFrame
df_imdb = pd.json_normalize(data)

# %%
# Save the DataFrame to a CSV file
df_imdb.to_csv('df_imbd.csv', index=False)

# %%
# View dataset
df_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5447 entries, 0 to 5446
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   adult                                3364 non-null   object
#  1   backdrop_path                        3136 non-null   object
#  2   belongs_to_collection                0 non-null      float64
#  3   budget                               3364 non-null   float64
#  4   genres                               3364 non-null   object
#  5   homepage                             3364 non-null   object
#  6   id                                   3364 non-null   float64
#  7   imdb_id                              3364 non-null   object
#  8   original_language                    3364 non-null   object
#  9   original_title                       3364 non-null   object
#  10  overview                             3364 non-null   object
#  11  popularity                           3364 non-null   float64
#  12  poster_path                          3323 non-null   object
#  13  production_companies                 3364 non-null   object
#  14  production_countries                 3364 non-null   object
#  15  release_date                         3364 non-null   object
#  16  revenue                              3364 non-null   float64
#  17  runtime                              3364 non-null   float64
#  18  spoken_languages                     3364 non-null   object
#  19  status                               3364 non-null   object
#  20  tagline                              3364 non-null   object
#  21  title                                3364 non-null   object
#  22  video                                3364 non-null   object
#  23  vote_average                         3364 non-null   float64
#  24  vote_count                           3364 non-null   float64
#  25  belongs_to_collection.id             408 non-null    float64
#  26  belongs_to_collection.name           408 non-null    object
#  27  belongs_to_collection.poster_path    320 non-null    object
#  28  belongs_to_collection.backdrop_path  269 non-null    object
# dtypes: float64(9), object(20)
# memory usage: 1.2+ MB

# %%
# View the dataframe
df_imdb.head()
# Out:
#    adult                     backdrop_path  belongs_to_collection     budget  \
# 0  False  /orjyEE9ZcMefTsN8zT5ryQTdkIz.jpg                    NaN  1300000.0
# 1  False  /jOaxen3pkKtD6vJm8sdHY6uVY3A.jpg                    NaN  2000000.0
# 2  False  /nWkxOXpctN2NuToGzwCSdFdiht0.jpg                    NaN   400000.0
# 3  False  /ccegwWa7I2vxxaoXrGB8Wl1g5nl.jpg                    NaN  5400000.0
# 4    NaN                               NaN                    NaN        NaN
#
#                                               genres  \
# 0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 12, 'name...
# 2  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 3  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4                                                NaN
#
#                                             homepage       id    imdb_id  \
# 0                                                       103.0  tt0075314
# 1              http://www.warnerbros.com/deliverance  10669.0  tt0068473
# 2  https://www.sonypictures.com/movies/montypytho...    762.0  tt0071853
# 3                                                      1654.0  tt0061578
# 4                                                NaN      NaN        NaN
#
#   original_language                   original_title  ...    status  \
# 0                en                      Taxi Driver  ...  Released
# 1                en                      Deliverance  ...  Released
# 2                en  Monty Python and the Holy Grail  ...  Released
# 3                en                  The Dirty Dozen  ...  Released
# 4               NaN                              NaN  ...       NaN
#
#                                              tagline  \
# 0  On every street in every city, there's a nobod...
# 1         What did happen on the Cahulawassee River?
# 2  And now! At Last! Another film completely diff...
# 3  Train them! Excite them! Arm them!...Then turn...
# 4                                                NaN
#
#                              title  video vote_average vote_count  \
# 0                      Taxi Driver  False        8.200    10564.0
# 1                      Deliverance  False        7.317     1340.0
# 2  Monty Python and the Holy Grail  False        7.804     5076.0
# 3                  The Dirty Dozen  False        7.611     1025.0
# 4                              NaN    NaN          NaN        NaN
#
#    belongs_to_collection.id  belongs_to_collection.name  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                  124492.0  The Dirty Dozen Collection
# 4                       NaN                         NaN
#
#   belongs_to_collection.poster_path belongs_to_collection.backdrop_path
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3  /3tNe3I17eUjQkHYz7XButEBlupJ.jpg    /z5Wj3wkksrRjyjhZ2flr00gSjTR.jpg
# 4                               NaN                                 NaN
#
# [5 rows x 29 columns]

# %%
# Remove the columns that we won'tneed
df_imdb = df_imdb.drop(['adult','backdrop_path',
                        'belongs_to_collection', 
                        'video','belongs_to_collection.id',
                        'belongs_to_collection.name',
                        'poster_path',
                        'belongs_to_collection.poster_path',
                        'belongs_to_collection.backdrop_path'], axis=1)

# %%
# Check columns 
df_imdb.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
# Check dataframe
df_imdb.head()
# Out:
#       budget                                             genres  \
# 0  1300000.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 1  2000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 12, 'name...
# 2   400000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 3  5400000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4        NaN                                                NaN
#
#                                             homepage       id    imdb_id  \
# 0                                                       103.0  tt0075314
# 1              http://www.warnerbros.com/deliverance  10669.0  tt0068473
# 2  https://www.sonypictures.com/movies/montypytho...    762.0  tt0071853
# 3                                                      1654.0  tt0061578
# 4                                                NaN      NaN        NaN
#
#   original_language                   original_title  \
# 0                en                      Taxi Driver
# 1                en                      Deliverance
# 2                en  Monty Python and the Holy Grail
# 3                en                  The Dirty Dozen
# 4               NaN                              NaN
#
#                                             overview  popularity  \
# 0  A mentally unstable Vietnam War veteran works ...      49.645
# 1  Intent on seeing the Cahulawassee River before...      16.623
# 2  King Arthur, accompanied by his squire, recrui...      27.025
# 3  12 American military prisoners in World War II...      21.143
# 4                                                NaN         NaN
#
#                                 production_companies  \
# 0  [{'id': 46059, 'logo_path': None, 'name': 'Ita...
# 1  [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...
# 2  [{'id': 416, 'logo_path': None, 'name': 'Pytho...
# 3  [{'id': 14159, 'logo_path': None, 'name': 'Sev...
# 4                                                NaN
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1976-02-09  28570902.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1972-08-18  46122355.0
# 2   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   1975-05-25   1940906.0
# 3  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   1967-06-15  45300000.0
# 4                                                NaN          NaN         NaN
#
#    runtime                                   spoken_languages    status  \
# 0    114.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     91.0  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 3    150.0  [{'english_name': 'Latin', 'iso_639_1': 'la', ...  Released
# 4      NaN                                                NaN       NaN
#
#                                              tagline  \
# 0  On every street in every city, there's a nobod...
# 1         What did happen on the Cahulawassee River?
# 2  And now! At Last! Another film completely diff...
# 3  Train them! Excite them! Arm them!...Then turn...
# 4                                                NaN
#
#                              title  vote_average  vote_count
# 0                      Taxi Driver         8.200     10564.0
# 1                      Deliverance         7.317      1340.0
# 2  Monty Python and the Holy Grail         7.804      5076.0
# 3                  The Dirty Dozen         7.611      1025.0
# 4                              NaN           NaN         NaN

# %%
# save this final dataframe as csv
# work on json column and gte the necessary data

# %% [markdown]
# # New CODE

# %%
import pandas as pd
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
df = pd.read_csv('df_imbd.csv')

# %%
imp_cols = ['adult', 'budget','genres','imdb_id','original_language','original_title','overview',
'popularity','production_companies','production_countries','revenue','runtime','spoken_languages','status','video','vote_average','vote_average']

# %%
df = df[imp_cols]

# %%
df.isna().sum()
# Out:
# adult                   2083
# budget                  2083
# genres                  2083
# imdb_id                 2083
# original_language       2083
# original_title          2083
# overview                2101
# popularity              2083
# production_companies    2083
# production_countries    2083
# revenue                 2083
# runtime                 2083
# spoken_languages        2083
# status                  2083
# video                   2083
# vote_average            2083
# vote_average            2083
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#       adult     budget                                             genres  \
# 0     False  1300000.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 1     False  2000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 12, 'name...
# 2     False   400000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 3     False  5400000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 5     False  4000000.0                     [{'id': 35, 'name': 'Comedy'}]
# ...     ...        ...                                                ...
# 5441  False        0.0                  [{'id': 16, 'name': 'Animation'}]
# 5442  False        0.0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 5443  False        0.0  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 5444  False        0.0  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 5445  False        0.0                     [{'id': 35, 'name': 'Comedy'}]
#
#          imdb_id original_language                     original_title  \
# 0      tt0075314                en                        Taxi Driver
# 1      tt0068473                en                        Deliverance
# 2      tt0071853                en    Monty Python and the Holy Grail
# 3      tt0061578                en                    The Dirty Dozen
# 5      tt0079470                en                      Life of Brian
# ...          ...               ...                                ...
# 5441  tt14586752                en  Super Monsters: Once Upon a Rhyme
# 5442  tt14216488                ar                             عروستي
# 5443  tt13857480                en                          Fine Wine
# 5444  tt11803618                ta                    கேர் ஆஃப் காதல்
# 5445  tt14585902                es                         Mi otra yo
#
#                                                overview  popularity  \
# 0     A mentally unstable Vietnam War veteran works ...      49.645
# 1     Intent on seeing the Cahulawassee River before...      16.623
# 2     King Arthur, accompanied by his squire, recrui...      27.025
# 3     12 American military prisoners in World War II...      21.143
# 5     Brian Cohen is an average young Jewish man, bu...      22.461
# ...                                                 ...         ...
# 5441  From Goldilocks to Hansel and Gretel, the Supe...      12.941
# 5442  The story follows a young man and woman who go...       2.448
# 5443  After falling for a woman much younger than hi...       2.197
# 5444  A heartwarming film that explores the concept ...       3.549
# 5445  A controversial TV host and comedian who has b...       6.343
#
#                                    production_companies  \
# 0     [{'id': 46059, 'logo_path': None, 'name': 'Ita...
# 1     [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...
# 2     [{'id': 416, 'logo_path': None, 'name': 'Pytho...
# 3     [{'id': 14159, 'logo_path': None, 'name': 'Sev...
# 5     [{'id': 20076, 'logo_path': '/i9qXGJIP9fGN22PP...
# ...                                                 ...
# 5441                                                 []
# 5442                                                 []
# 5443                                                 []
# 5444  [{'id': 86205, 'logo_path': '/cuepc2zGdotXIuZj...
# 5445  [{'id': 51949, 'logo_path': '/9Z5KwkBPIEJmJCJB...
#
#                                    production_countries     revenue  runtime  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...  28570902.0    114.0
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...  46122355.0    109.0
# 2      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   1940906.0     91.0
# 3     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...  45300000.0    150.0
# 5      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]  20745728.0     94.0
# ...                                                 ...         ...      ...
# 5441  [{'iso_3166_1': 'US', 'name': 'United States o...         0.0      0.0
# 5442            [{'iso_3166_1': 'EG', 'name': 'Egypt'}]         0.0     93.0
# 5443          [{'iso_3166_1': 'NG', 'name': 'Nigeria'}]         0.0    130.0
# 5444            [{'iso_3166_1': 'IN', 'name': 'India'}]         0.0    134.0
# 5445         [{'iso_3166_1': 'CO', 'name': 'Colombia'}]         0.0     89.0
#
#                                        spoken_languages    status  video  \
# 0     [{'english_name': 'English', 'iso_639_1': 'en'...  Released  False
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released  False
# 2     [{'english_name': 'French', 'iso_639_1': 'fr',...  Released  False
# 3     [{'english_name': 'Latin', 'iso_639_1': 'la', ...  Released  False
# 5     [{'english_name': 'English', 'iso_639_1': 'en'...  Released  False
# ...                                                 ...       ...    ...
# 5441  [{'english_name': 'English', 'iso_639_1': 'en'...  Released  False
# 5442  [{'english_name': 'Arabic', 'iso_639_1': 'ar',...  Released  False
# 5443  [{'english_name': 'English', 'iso_639_1': 'en'...  Released  False
# 5444  [{'english_name': 'Tamil', 'iso_639_1': 'ta', ...  Released  False
# 5445  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released  False
#
#       vote_average  vote_average
# 0            8.200         8.200
# 1            7.317         7.317
# 2            7.804         7.804
# 3            7.611         7.611
# 5            7.755         7.755
# ...            ...           ...
# 5441         6.200         6.200
# 5442         5.600         5.600
# 5443         2.000         2.000
# 5444         6.000         6.000
# 5445         6.300         6.300
#
# [3346 rows x 17 columns]

# %%
[d['name'] for d in eval(df['genres'][0])]
# Out:
# ['Crime', 'Drama']

# %%
[d['name'] for d in eval(df['production_countries'][0])]
# Out:
# ['United States of America']

# %%
eval(df['production_countries'][0])
# Out:
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]

# %%
[d['name'] for d in eval(df['production_companies'][0])]
# Out:
# ['Italo/Judeo Productions', 'Bill/Phillips', 'Columbia Pictures']

# %%
[d['name'] for d in eval(df['spoken_languages'][0])]
# Out:
# ['English', 'Español']

# %%
eval(df['spoken_languages'][0])
# Out:
# [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'},
#  {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}]

# %%
def get_val(dictionary_list):
    val = [d['name'] for d in eval(dictionary_list)]
    return val

# %%
df['genres'] = df['genres'].progress_apply(lambda x: get_val(x))
# Out:
#   0%|          | 0/3346 [00:00<?, ?it/s]

# %%
df['production_countries'] = df['production_countries'].progress_apply(lambda x: get_val(x))
df['production_companies'] = df['production_companies'].progress_apply(lambda x: get_val(x))
df['spoken_languages'] = df['spoken_languages'].progress_apply(lambda x: get_val(x))
# Out:
#   0%|          | 0/3346 [00:00<?, ?it/s]
#   0%|          | 0/3346 [00:00<?, ?it/s]
#   0%|          | 0/3346 [00:00<?, ?it/s]

# %%
df[df['revenue']!=0]
# Out:
#       adult     budget                                  genres     imdb_id  \
# 0     False  1300000.0                          [Crime, Drama]   tt0075314
# 1     False  2000000.0            [Drama, Adventure, Thriller]   tt0068473
# 2     False   400000.0            [Adventure, Comedy, Fantasy]   tt0071853
# 3     False  5400000.0                [Action, Adventure, War]   tt0061578
# 5     False  4000000.0                                [Comedy]   tt0079470
# ...     ...        ...                                     ...         ...
# 5180  False        0.0  [Animation, Adventure, Family, Comedy]   tt9038290
# 5207  False        0.0                          [Crime, Drama]  tt13356884
# 5274  False        0.0                      [Action, Thriller]  tt11503178
# 5304  False        0.0    [Comedy, Science Fiction, Adventure]  tt13043436
# 5367  False        0.0                                [Comedy]  tt12738164
#
#      original_language                           original_title  \
# 0                   en                              Taxi Driver
# 1                   en                              Deliverance
# 2                   en          Monty Python and the Holy Grail
# 3                   en                          The Dirty Dozen
# 5                   en                            Life of Brian
# ...                ...                                      ...
# 5180                de  Latte Igel und der magische Wasserstein
# 5207                ja                        ヤクザと家族 The Family
# 5274                te                                 Wild Dog
# 5304                ar                             الإنس والنمس
# 5367                tr                           Aykut Enişte 2
#
#                                                overview  popularity  \
# 0     A mentally unstable Vietnam War veteran works ...      49.645
# 1     Intent on seeing the Cahulawassee River before...      16.623
# 2     King Arthur, accompanied by his squire, recrui...      27.025
# 3     12 American military prisoners in World War II...      21.143
# 5     Brian Cohen is an average young Jewish man, bu...      22.461
# ...                                                 ...         ...
# 5180  When a greedy bear steals a magic stone to kee...      20.206
# 5207  Taken in by the yakuza at a young age, Kenji s...       9.253
# 5274  Wild Dog aka Vijay Varma is an NIA agent who’s...       4.645
# 5304  The story follows a poor government employee w...       2.554
# 5367  On the eve of his wedding, a young man must de...       2.689
#
#                                    production_companies  \
# 0     [Italo/Judeo Productions, Bill/Phillips, Colum...
# 1            [Warner Bros. Pictures, Elmer Enterprises]
# 2     [Python (Monty) Pictures Limited, Michael Whit...
# 3       [Seven Arts Pictures, MKH, Metro-Goldwyn-Mayer]
# 5     [HandMade Films, Python (Monty) Pictures Limited]
# ...                                                 ...
# 5180  [Dreamin' Dolphin Film, Eagle Eye Filmprodukti...
# 5207                             [STAR SANDS, KADOKAWA]
# 5274                            [Matinee Entertainment]
# 5304                         [Al-Masa Media Production]
# 5367                                              [BKM]
#
#                             production_countries     revenue  runtime  \
# 0                     [United States of America]  28570902.0    114.0
# 1                     [United States of America]  46122355.0    109.0
# 2                               [United Kingdom]   1940906.0     91.0
# 3     [United Kingdom, United States of America]  45300000.0    150.0
# 5                               [United Kingdom]  20745728.0     94.0
# ...                                          ...         ...      ...
# 5180                          [Belgium, Germany]   4983582.0     89.0
# 5207                                     [Japan]   2168905.0    136.0
# 5274                                     [India]     32519.0    122.0
# 5304                                     [Egypt]   3487821.0    120.0
# 5367                                    [Turkey]   2551748.0    118.0
#
#                                   spoken_languages    status  video  \
# 0                               [English, Español]  Released  False
# 1                                        [English]  Released  False
# 2                       [Français, Latin, English]  Released  False
# 3     [Latin, English, Deutsch, Français, Español]  Released  False
# 5                                 [English, Latin]  Released  False
# ...                                            ...       ...    ...
# 5180                                     [Deutsch]  Released  False
# 5207                                    [普通话, 日本語]  Released  False
# 5274                                      [తెలుగు]  Released  False
# 5304                                     [العربية]  Released  False
# 5367                                      [Türkçe]  Released  False
#
#       vote_average  vote_average
# 0            8.200         8.200
# 1            7.317         7.317
# 2            7.804         7.804
# 3            7.611         7.611
# 5            7.755         7.755
# ...            ...           ...
# 5180         6.700         6.700
# 5207         7.200         7.200
# 5274         5.067         5.067
# 5304         4.100         4.100
# 5367         6.500         6.500
#
# [653 rows x 17 columns]

# %%
dd = pd.read_csv(r'D:\OneDrive - NITT\Desktop\full_proj_v2\data.tsv',delimiter='\t')
# Out:
# C:\Users\avitr\AppData\Local\Temp\ipykernel_25148\791374562.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dd = pd.read_csv(r'D:\OneDrive - NITT\Desktop\full_proj_v2\data.tsv',delimiter='\t')

# %%
dd.shape
# Out:
# (35704646, 8)

# %%
imdb_id = list(set(dd['titleId']))

# %%
import random
random.seed(100)

# %%
small_imdb_id = random.sample(imdb_id,50000)

# %%
pd.DataFrame(small_imdb_id[:25000]).to_csv('imdb1.csv')

# %%
data_all = []
for id_ in tqdm(small_imdb_id[25000:]):
    json_data = get_json(id_)
    data_all.append(json_data)
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]

# %%
import json

with open('data.json', 'w') as fp:
    json.dump(data_all, fp)
