# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Importing-Libraries" data-toc-modified-id="Importing-Libraries-0.1">Importing Libraries</a></span></li><li><span><a href="#Importing-the-dataset" data-toc-modified-id="Importing-the-dataset-0.2">Importing the dataset</a></span><ul class="toc-item"><li><span><a href="#Distribution-of-Data---Target" data-toc-modified-id="Distribution-of-Data---Target-0.2.1">Distribution of Data - Target</a></span></li><li><span><a href="#Steps-to-clean-the-data" data-toc-modified-id="Steps-to-clean-the-data-0.2.2">Steps to clean the data</a></span></li></ul></li><li><span><a href="#Pre-process-Text" data-toc-modified-id="Pre-process-Text-0.3">Pre-process Text</a></span></li><li><span><a href="#Word-Cloud" data-toc-modified-id="Word-Cloud-0.4">Word Cloud</a></span></li><li><span><a href="#Split-Data" data-toc-modified-id="Split-Data-0.5">Split Data</a></span></li><li><span><a href="#TF-IDF" data-toc-modified-id="TF-IDF-0.6">TF-IDF</a></span></li><li><span><a href="#CountVectorizer" data-toc-modified-id="CountVectorizer-0.7">CountVectorizer</a></span></li></ul></li><li><span><a href="#Word-Embedding-using-Word2Vec" data-toc-modified-id="Word-Embedding-using-Word2Vec-1">Word Embedding using Word2Vec</a></span><ul class="toc-item"><li><span><a href="#Hyperparameter-Tuning-using-GridSearch" data-toc-modified-id="Hyperparameter-Tuning-using-GridSearch-1.1">Hyperparameter Tuning using GridSearch</a></span><ul class="toc-item"><li><span><a href="#Random-Forest---Hyperparameter-Tuning" data-toc-modified-id="Random-Forest---Hyperparameter-Tuning-1.1.1">Random Forest - Hyperparameter Tuning</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Importing Libraries

# %%
# Import Sklearn libraries to build models 
from sklearn.feature_extraction.text import TfidfVectorizer #  TF-IDF to vectorize words 
from sklearn.metrics import classification_report, confusion_matrix 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
# from sklearn.metrics import plot_confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import GridSearchCV
# Import Libraries to perform computation and do visualization. 
import pandas as pd
import numpy as np
np.random.seed(0)
import seaborn as sns
import matplotlib.pyplot as plt
import string
import time
# Import nltk to check english lexicon.
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet, stopwords
from nltk import word_tokenize, FreqDist
from nltk import pos_tag # for Parts of Speech tagging
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Generate wordcloud for word distribution visualization.
from wordcloud import WordCloud 

# Generating random numbers.
import random 

from xgboost import XGBClassifier

# Transforms text to a fixed-length vector of integers.
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
import gensim
import os

import textdistance
#Efficient functions to search in strings.
import re as re 

# Import images for world cloud.
from PIL import Image, ImageDraw, ImageFont 


# # Keras
# from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
# from keras.models import Sequential
# from keras.layers import Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM
# from keras import utils
# from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Import Yellowbrick and vector coupon for visualization of frequent words
 
from yellowbrick.text import FreqDistVisualizer
from yellowbrick.datasets import load_hobbies

from tqdm.notebook import tqdm

from os import path
from os import environ

# %% [markdown]
# ### Importing the dataset

# %%
DATASET_COLUMNS=["sentiment", "ids", "date", "flag", "user", "tweet"]
DATASET_ENCODING = "ISO-8859-1"
ta_df = pd.read_csv(r'D:\OneDrive - NITT\Custom_Download\training.1600000.processed.noemoticon.csv', 
                    encoding=DATASET_ENCODING, names=DATASET_COLUMNS)

ta_df.head()
# Out:
#    sentiment         ids                          date      flag  \
# 0          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                              tweet
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
ta_df = ta_df.sample(500,random_state=42)

# %%
ta_df.shape
# Out:
# (500, 6)

# %%
ta_df.info()

# %%
ta_df.isna().mean()*100

# %%
ta_df['flag'].unique()

# %%
ta_df.drop(['flag','ids'], axis=1, inplace = True)

# %%
ta_df.head()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Checking length 
print('length of data is', len(ta_df))

# %% [markdown]
# #### Distribution of Data - Target

# %%
ta_df['sentiment'].unique()

# %%
ta_df['sentiment'].value_counts(normalize=True)*100

# %%
# Replacing the value 4 -->1 for ease of understanding.
# 0 = negative, 1 = positive
ta_df['sentiment'] = ta_df['sentiment'].replace(4,1)
ta_df.head()

# %%
# Plot the count plot for the target labels.


p = sns.countplot(data = ta_df, y = 'sentiment', palette="Set3") #Setting p to plot of Emotion
p.set(xlabel = 'count') #Labling X
p.set(ylabel = 'sentiment') #Labling Y
p.set(title = "Count of Tweets per Sentiment")

# %%
print('Count of columns in the data is:  ', len(ta_df.columns))
print('Count of rows in the data is:  ', len(ta_df))

# %% [markdown]
# #### Steps to clean the data
#
# * Checking and handling NaN values
# * Drop duplicate

# %%
ta_df.dropna(inplace=True)

# %%
len(ta_df.duplicated(keep='last'))

# %%
ta_df.drop_duplicates()
ta_df.info()

# %%
# Checking for Null values.  We use the heatmap code which shows the contrast well.

sns.heatmap(ta_df.isnull(), cbar=False)
plt.title("NaNs")
plt.xlabel('Culomns')
plt.ylabel('Row')
plt.show()

# %%
# Removing duplicate values
ta_df.drop_duplicates(inplace = True)

# %%
# Creating an independent copy  

ta_df_copy = ta_df.copy()

# %% [markdown]
# ### Pre-process Text
#
# We will use text processing to allow the data to be more digestible for model use later in this project. This is an integral step in Natural Language Processing (NLP).
#
#
# The Preprocessing steps taken are:
#
# * Converting to lower case letters: Each text will be transferred to a lower case letter.
#
# * Removing Stopwords: Stopwords are common words used in the English language and do not add meaning to the sentences. Therefore we can remove them without sacrificing the meaning of the sentence.
#
# * Removing Words  with 2 letters: Words with length less than 2 are removed.
#
# * Replacing http with space: Links starting with "http" or "https" or "www" are replaced by "
# ".
#
# * Lemmetizing

# %%
# Testing PorterStemmer

# %%
tqdm.pandas()
ps = PorterStemmer()

TEXT_CLEANING_RE = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"

# Replace 3 or more consecutive letters by 2 letter.
sequencePattern   = r"(.)\1\1+"
seqReplacePattern = r"\1\1"

stop_words = set(stopwords.words("english"))

def preprocess(text,apply_stem=True):
    # Remove link,user and special characters
    text = re.sub(TEXT_CLEANING_RE, ' ', str(text).lower()).strip()
    text = re.sub(sequencePattern, seqReplacePattern, text)
    
    tokens = []
    for token in text.split():
        if token not in stop_words:
            
            if apply_stem:
                tokens.append(ps.stem(token))
            else:
                tokens.append(token)
            
    return " ".join(tokens)

# %%
ta_df['clean_tweet'] = ta_df['tweet'].progress_apply(lambda x:preprocess(x,True))

# %%
ta_df['clean_tweet_wt_stem'] = ta_df['tweet'].progress_apply(lambda x:preprocess(x,False))

# %%
# ta_df.drop('clean_tweets',axis=1,inplace=True)

# %%
ta_df.head()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Word Cloud

# %%
def red_color_func(word, font_size, position, orientation, random_state=None,**kwargs):
    return tuple(Reds_9.colors[random.randint(6,8)])  # Function to help us generate wordcloud

# %%
# text = ta_df['clean_tweet_wt_stem']

# %%
# mask = np.array(Image.open('/kaggle/input/pics-proj/tu.png'))

# %%
def red_color_func(word, font_size, position, orientation, random_state=None,**kwargs):
    return tuple(Reds_9.colors[random.randint(6,8)])  # Function to help us generate wordcloud

# %%
all_words = ' '.join([text for text in ta_df['clean_tweet_wt_stem']])

wordcloud = WordCloud(width=800, height=500, random_state=21, 
                      max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
tweets = ta_df['clean_tweet_wt_stem']

# %%
tweet_negative = ta_df[ta_df['sentiment']==0]
tweet_positive = ta_df[ta_df['sentiment']==1]

# %%
tweet_negative = tweet_negative['clean_tweet_wt_stem']
tweet_positive = tweet_positive['clean_tweet_wt_stem']

# %%
img = Image.open('upvote.png')
img.resize((20, 20), Image.ANTIALIAS)
plt.imshow(img)

# %%
mask_d = Image.open('final.png')
mask_d.resize((20, 20), Image.ANTIALIAS)
plt.imshow(mask_d)

# %%
#tweets = ta_df['clean_tweet_wt_stem'] 
# Create a new dataframe for the tweets that have stemming

# %%
def wc(data, mask,fname):
    
    plt.figure(figsize = (50,50))
    
    wc = WordCloud(width = 300, height = 200,background_color='white',
                   max_words = 50,  max_font_size =300,
                   colormap='rainbow',mask=mask)
    
    wc.generate(' '.join(data))
    
    plt.imshow(wc)
    plt.grid(visible=False)
    plt.savefig(f'{fname}.png',dpi=200)
#     plt.axis('off')

# %%
mask_pos = np.array(Image.open('upvote.png'))

wc(tweet_positive, mask_pos,'positive')

# %%
mask_neg = np.array(Image.open('final.png'))
wc(tweet_negative, mask_neg, 'negative')

# %%
#     pos_df = ta_df['clean_tweet'].loc[ta_df['sentiment'] == 1] 
#     #New dataframe of only positive rated tweet tokens

#     neg_df = ta_df['clean_tweet'].loc[ta_df['sentiment'] == 0] 
#     #New dataframe of only negative rated tweet tokens

# %%
pos_df = ta_df['clean_tweet'].loc[ta_df['sentiment'] == 1].progress_apply(lambda line:line.split())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pos_df = ta_df['clean_tweet'].loc[ta_df['sentiment'] == 1].progress_apply(lambda line:line.split())
#
# NameError: name 'ta_df' is not defined

# %%
neg_df = ta_df['clean_tweet'].loc[ta_df['sentiment'] == 0].progress_apply(lambda line:line.split())
# Out:
#   0%|          | 0/14999 [00:00<?, ?it/s]

# %%
tokens = [] #Instantiating total token list
tokens_pos = [] #Instantiating positive token list
tokens_neg = [] #Instantiating negative token list


for row in pos_df:
    tokens.extend(row) #Populating token list from dataframe
for row in pos_df:
    tokens_pos.extend(row) #Populating token list from dataframe
for row in neg_df:
    tokens_neg.extend(row) #Populating token list from dataframe

print(f'Total Corpus Tokens: {len(tokens)}') 
# Print total number of tokens
print(f'Number of Positive Tokens: {len(tokens_pos)}') 
# Print number of positive tokens
print(f'Number of Negative Tokens: {len(tokens_neg)}') 
# Print number of negative tokens
# Out:
# Total Corpus Tokens: 106777
# Number of Positive Tokens: 106777
# Number of Negative Tokens: 109861

# %%
tokens
# Out:
# ['lunch',
#  'dj',
#  'come',
#  'eat',
#  'thank',
#  'glad',
#  'like',
#  'product',
#  'review',
#  'bit',
#  'site',
#  'enjoy',
#  'knit',
#  'zach',
#  'make',
#  'pee',
#  'sit',
#  'grown',
#  'gay',
#  'man',
#  'sum',
#  'day',
#  'one',
#  'word',
#  'kacker',
#  'great',
#  'mind',
#  'think',
#  'alik',
#  'oh',
#  'realli',
#  'great',
#  'small',
#  'blizzard',
#  'also',
#  'cold',
#  'wind',
#  'blow',
#  'lol',
#  'calm',
#  'got',
#  '30day',
#  'loan',
#  'offer',
#  '1500',
#  'feel',
#  'quit',
#  'sleepi',
#  'today',
#  'wish',
#  'could',
#  'stay',
#  'bed',
#  'today',
#  'ok',
#  'last',
#  'year',
#  'let',
#  'go',
#  'school',
#  'whaddup',
#  'whaddup',
#  'whaddup',
#  'whaddup',
#  'whaddup',
#  'got',
#  'white',
#  'girl',
#  'swag',
#  'head',
#  'shoe',
#  'whaddup',
#  'yungla',
#  'will',
#  'pay',
#  '40',
#  '50',
#  'thu',
#  'cover',
#  'cost',
#  'set',
#  'one',
#  'got',
#  'counter',
#  'offer',
#  'listen',
#  'work',
#  'photo',
#  'hillsong',
#  '1',
#  'year',
#  'celebr',
#  'stay',
#  'tune',
#  'ww',
#  'hillsong',
#  'co',
#  'za',
#  'ha',
#  'ha',
#  'want',
#  'see',
#  'pictur',
#  'minist',
#  'boobi',
#  'flahs',
#  'im',
#  'turn',
#  '18',
#  'one',
#  'week',
#  'feel',
#  'excit',
#  'realli',
#  'know',
#  'seen',
#  'friend',
#  'got',
#  'excit',
#  'part',
#  'woork',
#  'tomorrow',
#  'amp',
#  'tuesday',
#  'get',
#  'ex',
#  'back',
#  'work',
#  'hahaha',
#  'blakk',
#  'reckkin',
#  'p',
#  'throw',
#  'cub',
#  'game',
#  'today',
#  'first',
#  'ever',
#  'hi',
#  'sound',
#  'like',
#  'feel',
#  'bit',
#  'better',
#  'great',
#  'great',
#  'day',
#  'lol',
#  'leav',
#  'kid',
#  'internet',
#  'kid',
#  'stupid',
#  'thing',
#  'eat',
#  'cha',
#  'eric',
#  'good',
#  'note',
#  'meet',
#  'marti',
#  'richard',
#  'red',
#  'ball',
#  'year',
#  'ago',
#  'sweet',
#  'never',
#  'forget',
#  'said',
#  'quot',
#  'scar',
#  'quot',
#  'sweeti',
#  'fck',
#  'br',
#  'ndbi',
#  '4',
#  '0',
#  'r',
#  'us',
#  'local',
#  'yocal',
#  'around',
#  'happi',
#  'find',
#  'u',
#  'twitter',
#  '2day',
#  'back',
#  'supercheap',
#  'success',
#  'trip',
#  'bike',
#  'tank',
#  'amp',
#  'check',
#  'week',
#  'readi',
#  'start',
#  'relax',
#  'good',
#  'work',
#  'welcom',
#  'new',
#  'cd',
#  'week',
#  'mayb',
#  'even',
#  'tomorrow',
#  'anyon',
#  'want',
#  'attend',
#  'tedm',
#  'make',
#  'date',
#  'happili',
#  'take',
#  'place',
#  'live',
#  'blog',
#  'mean',
#  'us',
#  'gocat',
#  'old',
#  'realli',
#  'watch',
#  'crank',
#  '2',
#  'awesom',
#  'night',
#  'rock',
#  'star',
#  'realli',
#  'reason',
#  'haha',
#  'sound',
#  'stupid',
#  '14',
#  'first',
#  'night',
#  'myer',
#  'w',
#  'lydia',
#  'actual',
#  'excit',
#  'summer',
#  'whipsnad',
#  'hope',
#  'dri',
#  'fine',
#  'kinder',
#  'cough',
#  'lot',
#  'sleep',
#  'weather',
#  'good',
#  'though',
#  'main',
#  'thing',
#  'listen',
#  'nutcrack',
#  'say',
#  'christma',
#  'thing',
#  'miss',
#  'cant',
#  'wait',
#  'see',
#  'im',
#  'happi',
#  'mourni',
#  'eh',
#  'morni',
#  'glad',
#  'blog',
#  'help',
#  'awesom',
#  'pumpkin',
#  'famou',
#  'haha',
#  'how',
#  'long',
#  'time',
#  'repli',
#  'seattl',
#  'pride',
#  'june',
#  '28th',
#  '11am',
#  'come',
#  'support',
#  'commun',
#  'march',
#  'marriag',
#  'equal',
#  'conting',
#  'seriosuli',
#  'second',
#  'one',
#  'quot',
#  'sinc',
#  'alreadi',
#  'mid',
#  'class',
#  'dude',
#  'would',
#  'work',
#  'food',
#  'quot',
#  'full',
#  'win',
#  'luv',
#  'lt',
#  '3',
#  'mean',
#  'catch',
#  'age',
#  '100',
#  'like',
#  'get',
#  'class',
#  'hi',
#  'seb',
#  'spanish',
#  'fan',
#  'addict',
#  'sp',
#  'think',
#  'best',
#  'band',
#  'world',
#  'pleas',
#  'come',
#  'spain',
#  'earli',
#  'home',
#  'soccer',
#  'hot',
#  'today',
#  'retreat',
#  'cool',
#  'basement',
#  'find',
#  'someon',
#  'quot',
#  'fugazi',
#  'patrol',
#  'quot',
#  'amp',
#  'motto',
#  'quot',
#  'u',
#  'see',
#  'clown',
#  'point',
#  'em',
#  'quot',
#  'pleas',
#  'let',
#  'everyon',
#  'know',
#  'us',
#  'ginorm',
#  'haha',
#  'well',
#  'feel',
#  'wierd',
#  'talk',
#  'myy',
#  'ziit',
#  'ta',
#  'ta',
#  'good',
#  'nightt',
#  'obsess',
#  'twit',
#  'haha',
#  'one',
#  'interlock',
#  'one',
#  'go',
#  'oh',
#  'got',
#  'case',
#  'design',
#  'someon',
#  'idiot',
#  'stole',
#  'prove',
#  'want',
#  'play',
#  'hardbal',
#  'game',
#  'congrat',
#  '4x',
#  'platinum',
#  'fantast',
#  'album',
#  'one',
#  'fav',
#  'yeahh',
#  'would',
#  'pretti',
#  'awesom',
#  'think',
#  'work',
#  'discoveri',
#  'channel',
#  'b',
#  'c',
#  'would',
#  'media',
#  'shark',
#  'green',
#  'day',
#  'new',
#  'cd',
#  '15th',
#  '16th',
#  'woo',
#  'watch',
#  'wayn',
#  'dyer',
#  'new',
#  'program',
#  'pb',
#  'quot',
#  'excus',
#  'begon',
#  'quot',
#  'lower',
#  'mainland',
#  'check',
#  'ch',
#  '27',
#  '204',
#  'shaw',
#  'peac',
#  'stop',
#  'listen',
#  'clip',
#  'jonasbroth',
#  'new',
#  'album',
#  'line',
#  'vine',
#  'tri',
#  'time',
#  'amaz',
#  'wait',
#  'whole',
#  'thing',
#  'know',
#  'think',
#  'air',
#  'cabl',
#  'channel',
#  'anymor',
#  'download',
#  'net',
#  'check',
#  'websit',
#  'idea',
#  'product',
#  'u',
#  'want',
#  'tri',
#  'sent',
#  'u',
#  'email',
#  'tomorrow',
#  'join',
#  'twitter',
#  'better',
#  'good',
#  'rain',
#  'suppos',
#  'today',
#  'complain',
#  'tho',
#  'love',
#  'amp',
#  'bright',
#  'happi',
#  'make',
#  'thank',
#  'took',
#  'two',
#  'minut',
#  'thank',
#  'style',
#  'envirowis',
#  'gov',
#  'uk',
#  'alreadi',
#  'take',
#  'ha',
#  'sound',
#  'wrong',
#  'staci',
#  'lmao',
#  'love',
#  'take',
#  'one',
#  'think',
#  'haha',
#  'youtub',
#  'waz7710',
#  'realli',
#  'ok',
#  'u',
#  'tri',
#  'em',
#  'u',
#  'see',
#  'work',
#  'doesnt',
#  'time',
#  'late',
#  'mornin',
#  'every1',
#  'hope',
#  'well',
#  'world',
#  'sure',
#  'work',
#  '7',
#  '45',
#  'mornin',
#  'guess',
#  'bad',
#  'take',
#  'critic',
#  'blame',
#  'without',
#  'resent',
#  'probabl',
#  'famili',
#  'dog',
#  'see',
#  'cheer',
#  'lou',
#  'ann',
#  'download',
#  'new',
#  'twitter',
#  'app',
#  'phone',
#  'much',
#  'better',
#  'alreadi',
#  'good',
#  'night',
#  'enjoy',
#  'morn',
#  'hang',
#  'juliet',
#  'victoria',
#  'know',
#  'yet',
#  'take',
#  'see',
#  'il',
#  'divo',
#  'tonight',
#  'fb',
#  'miss',
#  'bikini',
#  'philippin',
#  'pageant',
#  'thank',
#  'veggiecircl',
#  'ticket',
#  'go',
#  'global',
#  'friend',
#  'scott',
#  'think',
#  'love',
#  'brother',
#  'scottyholloway',
#  'take',
#  'love',
#  'sister',
#  'ho11i',
#  'old',
#  'town',
#  'dinn',
#  'dinn',
#  'amp',
#  'margarita',
#  'roast',
#  'cooker',
#  'cake',
#  'oven',
#  'soon',
#  'good',
#  'morn',
#  'hope',
#  'everyon',
#  'well',
#  'today',
#  'love',
#  'hair',
#  'dont',
#  'ever',
#  'cut',
#  'ur',
#  'lock',
#  'phew',
#  'hate',
#  'think',
#  'colin',
#  'fallen',
#  'glad',
#  'smile',
#  'hip',
#  'hip',
#  'hip',
#  'hooray',
#  'high',
#  'low',
#  'motiv',
#  'came',
#  'yay',
#  'finish',
#  'yet',
#  'well',
#  'way',
#  'gonna',
#  'go',
#  'finish',
#  'xx',
#  'schedul',
#  'soft',
#  'launch',
#  'tomorrow',
#  'even',
#  'alreadi',
#  'first',
#  'custom',
#  'lost',
#  'cat',
#  'quot',
#  'thank',
#  'lord',
#  'remind',
#  'see',
#  'way',
#  'see',
#  'quot',
#  'look',
#  'old',
#  'poster',
#  'bust',
#  'day',
#  'realli',
#  'short',
#  'hair',
#  'everythng',
#  'young',
#  'ta',
#  'old',
#  'home',
#  'long',
#  'day',
#  'work',
#  'wore',
#  'heel',
#  '11am',
#  '7pm',
#  'must',
#  'crazi',
#  'came',
#  'right',
#  'home',
#  'soak',
#  'feet',
#  'lol',
#  'wana',
#  'rub',
#  'em',
#  'tri',
#  'learn',
#  'quot',
#  'photographi',
#  'quot',
#  'sure',
#  'vote',
#  'competit',
#  'star',
#  'name',
#  'would',
#  'go',
#  'well',
#  'idol',
#  'trophi',
#  'love',
#  'sammoon',
#  'new',
#  'phone',
#  'tattoo',
#  'monday',
#  'woo',
#  'tea',
#  'yummi',
#  'comment',
#  'game',
#  'replay',
#  'complet',
#  'thank',
#  'everyon',
#  'serious',
#  'lucki',
#  'guy',
#  'great',
#  'love',
#  'friend',
#  'let',
#  'keep',
#  'touch',
#  'chuckisher',
#  'com',
#  'lax',
#  'talk',
#  'meet',
#  'tonight',
#  'tampa',
#  'chamber',
#  '6pm',
#  'womlinda',
#  'guest',
#  'speaker',
#  'word',
#  'mouth',
#  'market',
#  'happi',
#  'hour',
#  'tinatapa',
#  'success',
#  'obtain',
#  'visa',
#  'entri',
#  'enter',
#  'stay',
#  'royal',
#  'kingdom',
#  'thailand',
#  'downtown',
#  'disney',
#  'hahaha',
#  'scare',
#  'need',
#  'fresh',
#  'mind',
#  'grandpar',
#  'arriv',
#  'tomorrow',
#  'good',
#  'nite',
#  'good',
#  'chat',
#  'keep',
#  'u',
#  'post',
#  'guy',
#  'knoow',
#  'pizza',
#  'girl',
#  'episod',
#  'xd',
#  'lt',
#  '3',
#  'random',
#  'drunk',
#  'girl',
#  'sit',
#  'car',
#  'quot',
#  'man',
#  'bag',
#  'quot',
#  'quot',
#  'ye',
#  'man',
#  'bag',
#  'quot',
#  'btw',
#  'name',
#  'butch',
#  'lot',
#  'cool',
#  'ppl',
#  'gt',
#  'actionchick',
#  'thewildjok',
#  'walterdoc',
#  'jgdema',
#  'amilya',
#  'willig',
#  'followfriday',
#  'alright',
#  'debut',
#  'twitt',
#  'yay',
#  'lol',
#  'celeb',
#  'get',
#  'charact',
#  'rest',
#  'us',
#  'keyshia',
#  'cole',
#  'love',
#  'bebe',
#  'dang',
#  'brb',
#  'get',
#  'cake',
#  'candl',
#  'ice',
#  'cream',
#  'sing',
#  'happi',
#  'birthday',
#  'niec',
#  'sweet',
#  '16',
#  'olympu',
#  'e',
#  '410',
#  'besid',
#  'recent',
#  'digit',
#  'lens',
#  'also',
#  'got',
#  'old',
#  '50mm',
#  'om',
#  'len',
#  'mount',
#  'via',
#  'simpl',
#  'adapt',
#  'soo',
#  'happi',
#  'get',
#  'take',
#  'penguin',
#  'pic',
#  'collect',
#  'penguin',
#  'stuff',
#  'penguin',
#  'freak',
#  'wait',
#  'see',
#  'would',
#  'feel',
#  'taylorswift13',
#  'goberno',
#  'video',
#  'eh',
#  'eh',
#  'go',
#  'anywher',
#  'tarot',
#  'twread',
#  'next',
#  'lol',
#  'love',
#  'put',
#  'star',
#  'haha',
#  'cross',
#  'finger',
#  'hope',
#  'get',
#  'final',
#  'done',
#  'work',
#  'yay',
#  'sorri',
#  'miss',
#  'good',
#  'night',
#  'mumm',
#  'put',
#  'pizza',
#  'oven',
#  'haha',
#  'yeeahh',
#  'yeahh',
#  'know',
#  'till',
#  '2',
#  '30',
#  'bad',
#  'mm',
#  'mind',
#  'li',
#  'l',
#  'kati',
#  'either',
#  'jew',
#  'mood',
#  'download',
#  'futur',
#  'chase',
#  'light',
#  'naman',
#  'mamaya',
#  'haha',
#  'wish',
#  'kirstiealley',
#  'happi',
#  'mother',
#  'day',
#  'eu09',
#  '5',
#  'year',
#  'need',
#  'best',
#  'coverag',
#  'world',
#  'take',
#  'look',
#  'ye',
#  'europ',
#  'move',
#  'give',
#  'happi',
#  'thought',
#  'eatin',
#  'icecream',
#  'give',
#  'mark',
#  'birley',
#  'wear',
#  'later',
#  'week',
#  'even',
#  'though',
#  'quot',
#  'quiet',
#  'man',
#  'quot',
#  'happi',
#  'birthday',
#  'andi',
#  'hurley',
#  'hangin',
#  'besti',
#  'suzi',
#  'follow',
#  'last',
#  'nite',
#  'work',
#  'week',
#  'ah',
#  'im',
#  'good',
#  'humour',
#  'ahh',
#  'final',
#  'keep',
#  '5',
#  'guy',
#  'happi',
#  'get',
#  'wait',
#  'tonit',
#  'yay',
#  'realiz',
#  'drive',
#  'trip',
#  'twitter',
#  'thank',
#  'remind',
#  'actual',
#  'someth',
#  'mind',
#  'given',
#  'date',
#  'hint',
#  'star',
#  'trek',
#  'relat',
#  'brought',
#  'flask',
#  'v0dka',
#  'hahaha',
#  'ok',
#  'got',
#  'chang',
#  'background',
#  'go',
#  'watch',
#  ...]

# %%
def make_ngram(i, tokens_pos = tokens_pos, tokens_neg = tokens_neg): #Defining function
    
    n_gram_pos = (pd.Series(nltk.ngrams(tokens_pos, i)).value_counts())[:10] #Setting up positive ngram
    n_gram_neg = (pd.Series(nltk.ngrams(tokens_neg, i)).value_counts())[:10] #Setting up negative ngram
    
    n_gram_df_pos = pd.DataFrame(n_gram_pos) #Creating positive ngram dataframe
    n_gram_df_neg = pd.DataFrame(n_gram_neg) #Creating negative ngram dataframe
    
    n_gram_df_pos = n_gram_df_pos.reset_index() #Resetting index
    n_gram_df_neg = n_gram_df_neg.reset_index() #Resetting index
    
    n_gram_df_pos = n_gram_df_pos.rename(columns = {'index': 'Phrase', 0: 'Count'}) #Renaming positive plot
    n_gram_df_neg = n_gram_df_neg.rename(columns = {'index': 'Phrase', 0: 'Count'}) #Renaming negative plot
    
    with sns.axes_style('darkgrid'): #Setting seaborn to darkgrid style
        
        fig = plt.figure(figsize = (10, 10)) #Setting figsize
        ax1 = fig.add_subplot(311) #Stacking first figure
        ax2 = fig.add_subplot(312) #Stacking second figure
        
        sns.barplot(ax = ax1, x = 'Count', y = 'Phrase', data = n_gram_df_pos, 
                    palette = 'Greens_r').set(title = 'Positive Ngrams') #Assigning barplot to positive ngrams
        sns.barplot(ax = ax2, x = 'Count', y = 'Phrase', data = n_gram_df_neg, 
                   palette = 'Reds_r').set(title = 'Negative Ngrams') #Assigning barplot to negative ngrams
        
        
    plt.tight_layout() #Make plot layouts tight

make_ngram(1) #Plot 1 word ngrams

# %%
make_ngram(2) #Plot 2 word ngrams

# %%
make_ngram(3) #Plot 3 word ngrams

# %%
# Need to fix the above

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Split Data

# %%
X = ta_df['clean_tweet']#

y = ta_df['sentiment']#

# %%
list(set(ta_df['sentiment']))
# Out:
# [0, 1]

# %%
y.head()
# Out:
# 541200    0
# 750       0
# 766711    0
# 285055    0
# 705995    0
# Name: sentiment, dtype: int64

# %%
ta_df['sentiment'].value_counts()
# Out:
# 1    15000
# 0    14999
# Name: sentiment, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.25, 
                                                    random_state = 43)

# %%
# Checking shape of train and test data

print(X_train.shape, y_train.shape) 

print(X_test.shape , y_test.shape)
# Out:
# (22499,) (22499,)
# (7500,) (7500,)

# %%
### Visulization

# %% [markdown]
# ### TF-IDF

# %%
vectoriser_tfidf = TfidfVectorizer()

# %%
vectoriser_tfidf.fit(X_train)

print('Number of feature words:', len(vectoriser_tfidf.get_feature_names_out()))
# Out:
# Number of feature words: 18130

# %%
X_train_tfidf = vectoriser_tfidf.transform(X_train)
X_test_tfidf  = vectoriser_tfidf.transform(X_test)

# %%
# print(X_train_tfidf.toarray())

# %%
1199859*221591/1024/1024
# Out:
# 253560.97762012482

# %% [markdown]
# ### CountVectorizer

# %%
vectorizer_vc = CountVectorizer()
vectorizer_vc.fit(X_train)
# Out:
# CountVectorizer()

# %%
X_train_vc = vectorizer_vc.transform(X_train)
X_test_vc  = vectorizer_vc.transform(X_test)

# %%
# Building a function that will fit the model and then fit it to produce predicted values. 

def Train_Test_Scores(model,X_train,y_train,X_test,y_test,display=False):
    
    model.fit(X_train,y_train)
    y_preds = model.predict(X_test)
    
    # Store the score for later evaluation of the model. 
    
    train_acc = model.score(X_train,y_train)
    test_acc = model.score(X_test,y_test)
    precision = precision_score(y_test,y_preds)
    recall = recall_score(y_test,y_preds)
    f1 = f1_score(y_test,y_preds)
    
    # Allowing the display to switch off for later on when I just need to function to run 
    # for other purposes like creating a data frame of the scoring. 
    
    cm = confusion_matrix(y_test,y_preds)
    if display:
        print('Training_Accuracy:',  train_acc)
        print('Test_Accuracy:', test_acc)

        print('Precision:', precision)
        print('Recall:', recall) 
        print('F1_Score:', f1)
          
        disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
        disp.plot()
        plt.show()
          
          
    return train_acc,test_acc,precision,recall,f1

# %%
from tqdm.notebook import tqdm
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score,precision_score,recall_score

# %% [markdown]
# ## Word Embedding using Word2Vec

# %%
corpus = X.progress_apply(lambda line:line.split())
# Out:
#   0%|          | 0/29999 [00:00<?, ?it/s]

# %%
corpus
# Out:
# 541200                                       [ahh, hope, ok]
# 750                              [cool, tweet, app, razr, 2]
# 766711     [know, famili, drama, lame, hey, next, time, u...
# 285055     [school, email, open, geographi, stuff, revis,...
# 705995                              [upper, airway, problem]
#                                  ...
# 263962     [bout, go, eat, eat, sushi, phoboy86, hous, ho...
# 1540392               [guess, bu, ride, tour, bu, good, job]
# 1549636                                [hmm, might, go, bed]
# 706868     [sound, suspici, like, year, million, dream, h...
# 1027373                                            [problem]
# Name: clean_tweet, Length: 29999, dtype: object

# %%
# Train Word2Vec Model on corpus
import warnings
 
warnings.filterwarnings(action = 'ignore')
 
import gensim
from gensim.models import Word2Vec

model = Word2Vec(corpus, 
                 min_count=1,          # word frequency
                 vector_size=200,      # dimention of word embeddings
                 workers=os.cpu_count(),            # Number of processors
                 sg=1                  # 1 for skip-gram
                )

# %%
# pd.DataFrame((model.wv['ahh'] + model.wv['hope']  + model.wv['ok'])/3).T   #ahh, hope, ok]

# %%
ta_df['tokens'] = ta_df['clean_tweet'].progress_apply(lambda line:line.split())
# Out:
#   0%|          | 0/29999 [00:00<?, ?it/s]

# %%
ta_df.head()
# Out:
#         sentiment                          date             user  \
# 541200          0  Tue Jun 16 18:18:12 PDT 2009  LaLaLindsey0609
# 750             0  Mon Apr 06 23:11:14 PDT 2009      sexygrneyes
# 766711          0  Tue Jun 23 13:40:11 PDT 2009       sammydearr
# 285055          0  Mon Jun 01 10:26:07 PDT 2009      Lamb_Leanne
# 705995          0  Sat Jun 20 12:56:51 PDT 2009      yogicerdito
#
#                                                     tweet  \
# 541200             @chrishasboobs AHHH I HOPE YOUR OK!!!
# 750     @misstoriblack cool , i have no tweet apps  fo...
# 766711  @TiannaChaos i know  just family drama. its la...
# 285055  School email won't open  and I have geography ...
# 705995                             upper airways problem
#
#                                               clean_tweet  \
# 541200                                        ahh hope ok
# 750                                 cool tweet app razr 2
# 766711  know famili drama lame hey next time u hang ki...
# 285055  school email open geographi stuff revis stupid...
# 705995                               upper airway problem
#
#                                       clean_tweet_wt_stem  \
# 541200                                        ahh hope ok
# 750                                cool tweet apps razr 2
# 766711  know family drama lame hey next time u hang ki...
# 285055  school email open geography stuff revise stupi...
# 705995                              upper airways problem
#
#                                                    tokens
# 541200                                    [ahh, hope, ok]
# 750                           [cool, tweet, app, razr, 2]
# 766711  [know, famili, drama, lame, hey, next, time, u...
# 285055  [school, email, open, geographi, stuff, revis,...
# 705995                           [upper, airway, problem]

# %%
ta_df = ta_df[ta_df['tokens'].apply(lambda line: True if len(line) else False)]

# %%
# ta_df   [   ta_df['tokens'].apply(lambda t: False if len(t) else True)      ]

# %%
ta_df['tokens']
# Out:
# 541200                                       [ahh, hope, ok]
# 750                              [cool, tweet, app, razr, 2]
# 766711     [know, famili, drama, lame, hey, next, time, u...
# 285055     [school, email, open, geographi, stuff, revis,...
# 705995                              [upper, airway, problem]
#                                  ...
# 263962     [bout, go, eat, eat, sushi, phoboy86, hous, ho...
# 1540392               [guess, bu, ride, tour, bu, good, job]
# 1549636                                [hmm, might, go, bed]
# 706868     [sound, suspici, like, year, million, dream, h...
# 1027373                                            [problem]
# Name: tokens, Length: 29854, dtype: object

# %%
ta_df
# Out:
#          sentiment                          date             user  \
# 541200           0  Tue Jun 16 18:18:12 PDT 2009  LaLaLindsey0609
# 750              0  Mon Apr 06 23:11:14 PDT 2009      sexygrneyes
# 766711           0  Tue Jun 23 13:40:11 PDT 2009       sammydearr
# 285055           0  Mon Jun 01 10:26:07 PDT 2009      Lamb_Leanne
# 705995           0  Sat Jun 20 12:56:51 PDT 2009      yogicerdito
# ...            ...                           ...              ...
# 263962           0  Sun May 31 19:12:32 PDT 2009          gmlee86
# 1540392          1  Mon Jun 15 10:27:18 PDT 2009    KimoraEssence
# 1549636          1  Mon Jun 15 14:35:20 PDT 2009      LukeBarnett
# 706868           0  Sat Jun 20 13:21:24 PDT 2009    momspanelerin
# 1027373          1  Tue May 26 21:28:56 PDT 2009   RayleneOrnelas
#
#                                                      tweet  \
# 541200              @chrishasboobs AHHH I HOPE YOUR OK!!!
# 750      @misstoriblack cool , i have no tweet apps  fo...
# 766711   @TiannaChaos i know  just family drama. its la...
# 285055   School email won't open  and I have geography ...
# 705995                              upper airways problem
# ...                                                    ...
# 263962   Bout to go eat all you can eat sushi by @Phobo...
# 1540392  guess the only bus you ride now is your own to...
# 1549636                             Hmmm, might go to bed
# 706868   This sounds suspiciously like Year of a Millio...
# 1027373                        @MadisenHill no problem!!!
#
#                                                clean_tweet  \
# 541200                                         ahh hope ok
# 750                                  cool tweet app razr 2
# 766711   know famili drama lame hey next time u hang ki...
# 285055   school email open geographi stuff revis stupid...
# 705995                                upper airway problem
# ...                                                    ...
# 263962   bout go eat eat sushi phoboy86 hous hope eat e...
# 1540392                     guess bu ride tour bu good job
# 1549636                                   hmm might go bed
# 706868   sound suspici like year million dream hyatt co...
# 1027373                                            problem
#
#                                        clean_tweet_wt_stem  \
# 541200                                         ahh hope ok
# 750                                 cool tweet apps razr 2
# 766711   know family drama lame hey next time u hang ki...
# 285055   school email open geography stuff revise stupi...
# 705995                               upper airways problem
# ...                                                    ...
# 263962   bout go eat eat sushi phoboy86 house hopefully...
# 1540392                   guess bus ride tour bus good job
# 1549636                                   hmm might go bed
# 706868   sounds suspiciously like year million dreams h...
# 1027373                                            problem
#
#                                                     tokens
# 541200                                     [ahh, hope, ok]
# 750                            [cool, tweet, app, razr, 2]
# 766711   [know, famili, drama, lame, hey, next, time, u...
# 285055   [school, email, open, geographi, stuff, revis,...
# 705995                            [upper, airway, problem]
# ...                                                    ...
# 263962   [bout, go, eat, eat, sushi, phoboy86, hous, ho...
# 1540392             [guess, bu, ride, tour, bu, good, job]
# 1549636                              [hmm, might, go, bed]
# 706868   [sound, suspici, like, year, million, dream, h...
# 1027373                                          [problem]
#
# [29854 rows x 7 columns]

# %%
X_w2v = ta_df['tokens']#[:50000]
y_w2v = ta_df['sentiment']#[:50000]

# %%
len(X_w2v)
# Out:
# 29854

# %%
# model.wv.get_vector('there')

# %%
all_word2vec_vocab = set(model.wv.key_to_index)

# %%
def get_embed(token_list):
    n = len(token_list)
    embed = np.zeros((200))
    for token in token_list:
        if token in all_word2vec_vocab:
            embed = embed + model.wv.get_vector(token)
        else:
            temp = sorted([(textdistance.levenshtein.normalized_distance(e,token), e) for e in all_word2vec_vocab],reverse=False)[0][1]
            embed = embed + model.wv.get_vector(temp)
    return embed/n

# %%
X_w2v_embed = X_w2v.progress_apply(get_embed)
# Out:
#   0%|          | 0/29854 [00:00<?, ?it/s]

# %%
X_w2v_embed
# Out:
# 541200     [0.08763311803340912, -0.007221787236630917, -...
# 750        [0.08058064933866263, -0.03413456156849861, -0...
# 766711     [0.15021926164627075, -0.016989638575499778, -...
# 285055     [0.020268284482881427, -0.008339900872670114, ...
# 705995     [0.059941801242530346, -0.013450077967718244, ...
#                                  ...
# 263962     [0.06876371773507665, -0.044510969289523715, -...
# 1540392    [0.0814224650052243, -0.0016726577887311578, -...
# 1549636    [0.013346261344850063, 0.003271654713898897, -...
# 706868     [0.0969749252544716, -0.03989229307990172, -0....
# 1027373    [0.10303078591823578, -0.04894201457500458, -0...
# Name: tokens, Length: 29854, dtype: object

# %%
# get_embed(['hi','there'])

# %%
df_new = pd.DataFrame(X_w2v_embed)

# %%
df_new.reset_index(drop=True,inplace=True)

# %%
df_new
# Out:
#                                                   tokens
# 0      [0.08763311803340912, -0.007221787236630917, -...
# 1      [0.08058064933866263, -0.03413456156849861, -0...
# 2      [0.15021926164627075, -0.016989638575499778, -...
# 3      [0.020268284482881427, -0.008339900872670114, ...
# 4      [0.059941801242530346, -0.013450077967718244, ...
# ...                                                  ...
# 29849  [0.06876371773507665, -0.044510969289523715, -...
# 29850  [0.0814224650052243, -0.0016726577887311578, -...
# 29851  [0.013346261344850063, 0.003271654713898897, -...
# 29852  [0.0969749252544716, -0.03989229307990172, -0....
# 29853  [0.10303078591823578, -0.04894201457500458, -0...
#
# [29854 rows x 1 columns]

# %%
df_new[list(range(200))] = pd.DataFrame(df_new.tokens.tolist(), index= df_new.index)

# %%
df_new.drop('tokens',axis=1,inplace=True)

# %%
df_new
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.087633 -0.007222 -0.030302  0.251336  0.084225 -0.219203  0.072164
# 1      0.080581 -0.034135 -0.042745  0.046710  0.150905 -0.244528  0.006987
# 2      0.150219 -0.016990 -0.080578  0.098195  0.100327 -0.254575  0.064485
# 3      0.020268 -0.008340 -0.015824  0.148759  0.129182 -0.226433 -0.007459
# 4      0.059942 -0.013450 -0.002661  0.040231  0.068208 -0.133878 -0.009556
# ...         ...       ...       ...       ...       ...       ...       ...
# 29849  0.068764 -0.044511 -0.049159  0.154289  0.100153 -0.174258 -0.000990
# 29850  0.081422 -0.001673 -0.023613  0.142348  0.134714 -0.201332  0.029077
# 29851  0.013346  0.003272 -0.045564  0.152887  0.099645 -0.182320  0.063564
# 29852  0.096975 -0.039892 -0.063324  0.046170  0.153887 -0.128271 -0.006905
# 29853  0.103031 -0.048942 -0.026127  0.078505  0.131614 -0.263477  0.035249
#
#             7         8         9    ...       190       191       192  \
# 0      0.364526 -0.109819  0.149743  ...  0.252519 -0.142303 -0.221585
# 1      0.295005 -0.040908  0.100038  ...  0.190812 -0.051804 -0.065010
# 2      0.327877 -0.022566  0.123395  ...  0.212771 -0.130329 -0.125792
# 3      0.361585 -0.130008  0.167018  ...  0.252370 -0.090668 -0.142462
# 4      0.157243 -0.066888  0.068094  ...  0.100305 -0.058545 -0.034529
# ...         ...       ...       ...  ...       ...       ...       ...
# 29849  0.328624 -0.125320  0.138450  ...  0.221889 -0.121194 -0.145634
# 29850  0.316705 -0.108958  0.110246  ...  0.252023 -0.136377 -0.170854
# 29851  0.375116 -0.156460  0.132183  ...  0.263449 -0.150597 -0.227048
# 29852  0.239652 -0.030308  0.057147  ...  0.174568 -0.097190 -0.070955
# 29853  0.285906 -0.111513  0.106534  ...  0.209457 -0.112960 -0.121528
#
#             193       194       195       196       197       198       199
# 0     -0.448812  0.259808  0.133979  0.209813 -0.283725 -0.060660 -0.355957
# 1     -0.205999  0.204342  0.091194  0.228677 -0.213438 -0.123637 -0.185180
# 2     -0.308282  0.208453  0.152179  0.262737 -0.250417 -0.126992 -0.268347
# 3     -0.298217  0.187477  0.131101  0.186606 -0.215997 -0.071268 -0.272946
# 4     -0.102589  0.101436  0.064374  0.088292 -0.084638 -0.053969 -0.080479
# ...         ...       ...       ...       ...       ...       ...       ...
# 29849 -0.269704  0.151567  0.125069  0.139224 -0.216532 -0.113984 -0.263475
# 29850 -0.311172  0.203051  0.112516  0.213568 -0.279358 -0.063917 -0.302557
# 29851 -0.374533  0.155634  0.117412  0.243935 -0.214677 -0.148235 -0.353547
# 29852 -0.186918  0.090541  0.106704  0.119464 -0.169744 -0.085967 -0.178775
# 29853 -0.225621  0.192165  0.128458  0.189380 -0.171997 -0.129530 -0.187457
#
# [29854 rows x 200 columns]

# %%
X_train_w2v, X_test_w2v, y_train_w2v, y_test_w2v = train_test_split(df_new, y_w2v, test_size = 0.25, random_state = 43)

# %%
# %%time
# Creating a data frame to collect all the results and evaluate them

models_DataFrame = pd.DataFrame(columns=['Vectorizer','Model','Train_Accuracy','Test_Accuracy',
                                         'Precision','Recall','F1_score'])
list_models = [GaussianNB(),
              RandomForestClassifier(n_jobs=-1),
               XGBClassifier(n_jobs=-1)
              ]

model_names = 'GaussianNB RandomForest XGboost'.split()

from tqdm import tqdm
x_probs  = []
pipe_models = []
predictions = []
for vector in ('TF-IDF','CountVector', 'Word2Vec'):
    print(vector)
    if vector == "TF-IDF":
        x_train_temp = X_train_tfidf.toarray()
        x_test_temp = X_test_tfidf.toarray()
        
    elif vector == 'CountVector':
        x_train_temp = X_train_vc.toarray()
        x_test_temp = X_test_vc.toarray()
        
    elif vector == 'word2vec':
        x_train_temp = X_train_w2v.toarray()
        x_test_temp = X_test_w2v.toarray()
    
    for model,model_name in tqdm(zip(list_models,model_names)):
        print(model)
        train_acc,test_acc,precision,recall,f1 = Train_Test_Scores(model,x_train_temp,
                                                                   y_train,x_test_temp,y_test)
    #     x_probs.append(x_prob)
    #     pipe_models.append(pipe_model)
        models_DataFrame.loc[len(models_DataFrame)] = [vector,model_name,train_acc,
                                                       test_acc,precision,recall,f1]
# Out:
# TF-IDF
# 0it [00:00, ?it/s]
# GaussianNB()
# 1it [00:51, 51.25s/it]
# RandomForestClassifier(n_jobs=-1)
# 2it [05:48, 196.13s/it]
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=-1, num_parallel_tree=None,
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None)
# [10:37:31] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 3it [45:05, 902.00s/it]
# CountVector
# 0it [00:00, ?it/s]
# GaussianNB()
# 1it [00:46, 46.46s/it]
# RandomForestClassifier(n_jobs=-1)
# 2it [1:01:31, 2163.54s/it]
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=-1, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
# [12:31:11] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 3it [1:51:36, 2232.31s/it]
# 0it [00:00, ?it/s]
# Word2Vec
# GaussianNB()
# 1it [00:40, 40.11s/it]
# RandomForestClassifier(n_jobs=-1)
# 2it [02:33, 83.05s/it]
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=-1, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
# [13:05:06] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 3it [31:47, 635.72s/it]
# CPU times: user 2h 42min 50s, sys: 5h 33min 27s, total: 8h 16min 17s
# Wall time: 3h 8min 30s

# %%
models_DataFrame
# Out:
#     Vectorizer         Model  Train_Accuracy  Test_Accuracy  Precision  \
# 0       TF-IDF    GaussianNB        0.758211       0.537733   0.602649
# 1       TF-IDF  RandomForest        0.994933       0.738000   0.725843
# 2       TF-IDF       XGboost        0.781546       0.726800   0.693236
# 3  CountVector    GaussianNB        0.734210       0.533067   0.615970
# 4  CountVector  RandomForest        0.995022       0.737733   0.728840
# 5  CountVector       XGboost        0.763723       0.728933   0.693385
# 6     Word2Vec    GaussianNB        0.734210       0.533067   0.615970
# 7     Word2Vec  RandomForest        0.995022       0.737600   0.729124
# 8     Word2Vec       XGboost        0.763723       0.728933   0.693385
#
#      Recall  F1_score
# 0  0.218633  0.320862
# 1  0.764015  0.744440
# 2  0.812600  0.748187
# 3  0.172985  0.270113
# 4  0.756273  0.742303
# 5  0.819808  0.751315
# 6  0.172985  0.270113
# 7  0.755206  0.741935
# 8  0.819808  0.751315

# %%
Train_Test_Scores(XGBClassifier(n_jobs=-1),X_train_tfidf,y_train,X_test_tfidf,y_test,True)
# Out:
# [13:24:55] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Training_Accuracy: 0.7852793457487
# Test_Accuracy: 0.7234666666666667
# Precision: 0.6896551724137931
# Recall: 0.8115323011211959
# F1_Score: 0.7456463085602159
# (0.7852793457487,
#  0.7234666666666667,
#  0.6896551724137931,
#  0.8115323011211959,
#  0.7456463085602159)

# %%
# from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# cm = confusion_matrix(y_test, predictions, labels=clf.classes_)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=clf.classes_)

# %%
# TODO:
# 1) try DT, RF
# 2) try grid search on the best model
# 3) explore Keras/tensorflow - kaggle. Multi layer perceptron
# https://www.kaggle.com/code/fchollet/simple-deep-mlp-with-keras
# https://www.kaggle.com/code/sathianpong/3-ways-to-implement-mlp-with-keras
# https://www.kaggle.com/code/shivamchaudhary11/iris-dataset-using-mlp-classifier-in-keras/notebook
# https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html

# %%
STOP
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-ee4decdca3b8> in <module>
# ----> 1 STOP
#
# NameError: name 'STOP' is not defined
