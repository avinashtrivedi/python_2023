# %%
#!pip install load_img
#!pip install resnet
#!pip install keras.applications.resnet50

# %%
import numpy as np
import pandas as pd
import cv2
import os
import random
import threading
import torch
from keras.models import Model
from keras.layers import Input, Conv2D, Lambda, Flatten, Dense
from keras.optimizers import Adam
from keras import backend as K
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.models import Sequential
from keras.layers.pooling import MaxPooling2D

# %% [markdown]
# defining the variables

# %%
face = 100 # size of the face frame in the picture
batch_size = 64 # size of the batch of pictures to be trained
epochs = 1
validation_image_path = r"D:\images\Validation_Images"
training_images_path = r"D:\images\Training_Images"
testing_images_path = r"D:\images\Testing_Images"

# %%
#function to load images
def load_images(path):
    images_list = []
    labels_list = []
    for class_folder in os.listdir(path):
        class_dir = os.path.join(path, class_folder)
        for filename in os.listdir(class_dir):
            image_path = os.path.join(class_dir, filename)
            img = load_and_process(image_path)
            images_list.append(img)
            labels_list.append(class_folder)
    images_list = np.array(images_list)
    labels_list = np.array(labels_list)
    return images_list, labels_list

# %%
def create_pairs(x, digit_indices):
    '''Positive and negative pair creation.
    Alternates between positive and negative pairs.
    '''
    pairs = []
    labels = []
    n = min([len(digit_indices[d]) for d in range(10)]) - 1
    
    for d in range(10):
        for i in range(n):
            z1, z2 = digit_indices[d][i], digit_indices[d][i + 1]
            pairs += [[x[z1], x[z2]]]
            inc = random.randrange(1, 10)
            dn = (d + inc) % 10
            z1, z2 = digit_indices[d][i], digit_indices[dn][i]
            pairs += [[x[z1], x[z2]]]
            labels += [1, 0]
            
    return np.array(pairs), np.array(labels)

def create_pairs_on_set(images, labels):
    
    digit_indices = [np.where(labels == i)[0] for i in set(train_labels)]
    pairs, y = create_pairs(images, digit_indices)
    y = y.astype('float32')
    
    return pairs, y

# %%
# function to load and preprocess an image
def load_and_process(image_path):
    img = load_img(image_path, target_size=(face, face,3))
    img = img_to_array(img)
    print(img.shape)
    img = preprocess_input(img)
    print(img.shape)
    return img

# %%
# load_and_process(r"D:\images\Training_Images\Aaron Eckhart\1.jpg")

# %%
# Define the input shape
input_shape = (face, face, 3)

# %%
# Define function to create the Siamese network
def create_siamese_network(input_shape):
    # Define the two inputs for the network
    input_a = Input(shape=input_shape)
    input_b = Input(shape=input_shape)
    
    # Define the shared convolutional layers
   # Define the shared convolutional layers
    conv1 = Conv2D(64, (3,3), activation='relu')
    #conv2 = MaxPooling2D()
    conv3 = Conv2D(128, (3,3), activation='relu')
    #conv4 = MaxPooling2D()
    conv5 = Conv2D(256, (3,3), activation='relu')
    #conv6 = MaxPooling2D()
    conv7 = Conv2D(512, (3,3), activation='relu')
  
    
    # Apply the convolutional layers to both inputs
    features_a = conv7(conv5(conv3(conv1(input_a))))
    features_b = conv7(conv5(conv3(conv1(input_b))))

    # Define the distance metric
    distance = Lambda(lambda x: K.abs(x[0] - x[1]))([features_a, features_b])

    # Flatten the output and add a fully-connected layer
    fc1 = Flatten()(distance)
    fc1 = Dense(64, activation='sigmoid')(fc1)

    # Define the final output
    output = Dense(1, activation='sigmoid')(fc1)

    # Define the model
    model = Model(inputs=[input_a, input_b], outputs=output)

    return model

# %% [markdown]
# load training images

# %%
train_images, train_labels = load_images(training_images_path)
# Out:
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# ...

# %%
tr_pairs, tr_y = create_pairs_on_set(train_images, train_labels)

# %% [markdown]
# load validation images

# %%
val_images, val_labels = load_images(validation_image_path)
# tr_pairs, tr_y = create_pairs_on_set(train_images, train_labels)
# Out:
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# ...

# %%
val_images.shape
# Out:
# (76, 100, 100, 3)

# %%
# Create the Siamese network
siamese_network = create_siamese_network(input_shape)

# %%
# Compile the model
siamese_network.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001))

# %%
wait
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 wait
#
# NameError: name 'wait' is not defined

# %%
siamese_network.fit([tr_pairs[:120,0],tr_pairs[120:240,1]], tr_y[:120], batch_size=batch_size, epochs=epochs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 siamese_network.fit([tr_pairs[:120,0],tr_pairs[120:240,1]], tr_y[:120], batch_size=batch_size, epochs=epochs)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
# ...

# %%
# Train the modeltrain_images
# siamese_network.fit([train_images,train_images], train_labels, batch_size=batch_size, epochs=epochs)

# %%
# Load the test image
test_image = load_and_process(r'D:\IE\Courses\Deep Learning\Group Project\3\Testing_Images\1.jpg')

# Compare the test image to each training image
scores = []
for val_image in val_images:
    score = siamese_network.predict([np.array([test_image]), np.array([val_image])])[0][0]
    scores.append(score)

# Find the index of the highest scoring image

# %%
threshold = 0.50

# %%
highest_score = max(scores)
highest_score

# %%
if highest_score > threshold:
    person = scores.index(max(scores))
    print(train_labels[person])
else:
    print("not Unidentified")

# %%
len(scores)
