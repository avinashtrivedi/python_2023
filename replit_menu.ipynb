# %%
import replit
from replit import clear
from getkey import getkey, keys

def tryck_enter_för_att_starta():
    input("Tryck enter för att starta Reseplaneraren\n")


#start funktion för att programmet skall sätta igång

print("Hej och välkomna till Tahas Resebyrå AB\n")
print("Här kommer vi kunna ta fram ett skräddarsytt resemål utifrån dina preferenser! Låt oss sätta igång.\n")

#intro text när användaren sätter igång programmet

input("Tryck enter för att välja vilket land du vill besöka")


def FirstChoice():
  replit.clear()
  print("Du har valt Italien. Ett utmärkt val!")


def SecondChoice():
  replit.clear()
  print("Du har valt Spanien. Ett utmärkt val!")


def ThirdChoice():
  replit.clear()
  print("Du har valt USA. Ett utmärkt val!")


def FourthChoice():
  replit.clear()
  print("Du har valt Australien. Ett utmärkt val!")


def vilket_land():
  # land = input()
  # return land

  menuOptions = ["Italien", "Spanien", "USA", "Australien"]
  menuSelected = 0
  while (True):

    replit.clear()
    print("\x1b[?25l")
    print("Här är de länder vi erbjuder resemål till idag:\n")

    if menuSelected == 0:
      print(menuOptions[0] + "<---")
      print(menuOptions[1])
      print(menuOptions[2])
      print(menuOptions[3])
    elif menuSelected == 1:
      print(menuOptions[0])
      print(menuOptions[1] + "<---")
      print(menuOptions[2])
      print(menuOptions[3])
    elif menuSelected == 2:
      print(menuOptions[0])
      print(menuOptions[1])
      print(menuOptions[2] + "<---")
      print(menuOptions[3])
    elif menuSelected == 3:
      print(menuOptions[0])
      print(menuOptions[1])
      print(menuOptions[2])
      print(menuOptions[3] + "<---")

    keyPressed = getkey()

    if keyPressed == keys.DOWN and menuSelected + 1 != len(menuOptions):
      menuSelected += 1
    elif keyPressed == keys.UP and not (menuSelected == 0):
      menuSelected -= 1
    elif keyPressed == keys.ENTER:

      if menuSelected == 0:
        valt_land = "Italien"
         replit.clear()
          print("Du har valt Italien. Ett utmärkt val!")
        FirstChoice()  # call FirstChoice() function if Italy is selected

        break
      elif menuSelected == 1:
        valt_land = "Spanien"
        SecondChoice()  # call SecondChoice() function if Spain is selected

        break
      elif menuSelected == 2:
        valt_land = "USA"
        ThirdChoice()  # call ThirdChoice() function if USA is selected

        break
      elif menuSelected == 3:
        valt_land = "Australien"
        FourthChoice()  # call FourthChoice() function if Australia is selected

        break
  return valt_land


def FirstAgeChoice():
  clear()
  print("Vi anpassar resan efter din ålder.")


def SecondAgeChoice():
  clear()
  print("Vi anpassar resan efter din ålder.")


def vilken_ålder():
  # ålder = input()
  # return ålder

  menuOptions = ["18-45", "46+"]
  menuSelected = 0

  while (True):
    clear()
    print("\x1b[?25l")
    clear()
    print(
      "För att på bästa sätt kunna anpassa resan efter dig vänligen välj en ålderskategori som passar dig bäst."
    )

    if menuSelected == 0:
      print(menuOptions[0] + "<---")
      print(menuOptions[1])
    elif menuSelected == 1:
      print(menuOptions[0])
      print(menuOptions[1] + "<---")

    keyPressed = getkey()
    if keyPressed == keys.DOWN and menuSelected + 1 != len(menuOptions):
      menuSelected += 1
    elif keyPressed == keys.UP and not (menuSelected == 0):
      menuSelected -= 1
    elif keyPressed == keys.ENTER:
      if menuSelected == 0:
        age_category = "18-45"
        FirstAgeChoice()
        break
      elif menuSelected == 1:
        age_category = "46+"
        SecondAgeChoice()
        break
  return age_category


# input("Tryck Enter för att fortsätta programmet..")


#funktion för användaren fyller i hur gamla dom är
def FirstBudgetChoice():
  replit.clear()
  print(
    "Du har en bra budget, vi skall nog kunna hitta en perfekt resa för dig. Vi anpassar resan efter din angivna budget."
  )


def SecondBudgetChoice():
  replit.clear()
  print(
    "Du har en stor budget, du gillar säkerligen lyx och annat trevligt. Vi anpassar resan efter din angivna budget."
  )


def vilken_budget():
  # budget = input()
  # return budget

  menuOptions = ["10-15 000:-", "15 000:- +"]
  menuSelected = 0
  while (True):
    replit.clear()
    print("\x1b[?25l")
    clear()
    print(
      "Nu när du har valt vilket land, samt vilket åldersspann du tillhör skulle vi gärna vilja veta vilken budget nivå som passar dig bäst av följande:"
    )

    if menuSelected == 0:
      print(menuOptions[0] + "<---")
      print(menuOptions[1])
    elif menuSelected == 1:
      print(menuOptions[0])
      print(menuOptions[1] + "<---")

    keyPressed = getkey()
    if keyPressed == keys.DOWN and menuSelected + 1 != len(menuOptions):
      menuSelected += 1
    elif keyPressed == keys.UP and not (menuSelected == 0):
      menuSelected -= 1
    elif keyPressed == keys.ENTER:
      if menuSelected == 0:
        FirstBudgetChoice()
        budget = "10-15 000:-"
        break
      elif menuSelected == 1:
        SecondBudgetChoice()
        budget = "15 000:- +"
        break
  return budget


# input("Tryck Enter för att fortsätta programmet..")

#funktion för användaren fyller i sin budget


def FirstHobbyChoice():
  replit.clear()
  print(
    "Du är en person som söker mycket sol och bad. Vi ska nog kunna hitta en resa enligt de preferenserna!"
  )


def SecondHobbyChoice():
  replit.clear()
  print(
    "Du är en person som gillar lugn och ro, så vi ska nog titta lite på utkanter av städer och eventuellt barnfria alternativ."
  )


def vilken_syssla():
  # syssla = input()
  # return syssla

  menuOptions = ["Sol och bad", "Lugnt och harmoniskt"]
  menuSelected = 0
  while (True):
    replit.clear()
    print("\x1b[?25l")
    clear()
    print(
      "Nu är du nästan klar. Den sista frågan är gällande vad du är ute efter på din semester, välj ett av följande:"
    )

    if menuSelected == 0:
      print(menuOptions[0] + "<---")
      print(menuOptions[1])
    elif menuSelected == 1:
      print(menuOptions[0])
      print(menuOptions[1] + "<---")

    keyPressed = getkey()
    if keyPressed == keys.DOWN and menuSelected + 1 != len(menuOptions):
      menuSelected += 1
    elif keyPressed == keys.UP and not (menuSelected == 0):
      menuSelected -= 1
    elif keyPressed == keys.ENTER:
      if menuSelected == 0:
        FirstHobbyChoice()
        hobby_choice = menuOptions[0]
        break
      elif menuSelected == 1:
        SecondHobbyChoice()
        hobby_choice = menuOptions[1]
        break
  return hobby_choice


def give_suggestions():
  print('inside main')
  # Call the functions to get the user's choices and store their return values in variables
  land = vilket_land()
  ålder = vilken_ålder()
  budget = vilken_budget()
  syssla = vilken_syssla()

  # Give a suggestion based on the user's choices
  print("Based on your choices, we suggest the following vacation:")
  if land == "Italien" and ålder == "18-45" and budget == "10-15 000:-" and syssla == "Sol och bad":
    print("- Amalfikusten")
  elif land == "Italien" and ålder == "18-45" and budget == "10-15 000:-" and syssla == "Aktiviteter":
    print("- Rom")
  elif land == "Spanien" and ålder == "18-45" and budget == "10-15 000:-" and syssla == "Sol och bad":
    print("- Costa del Sol")
  elif land == "Spanien" and ålder == "18-45" and budget == "10-15 000:-" and syssla == "Aktiviteter":
    print("- Barcelona")
  elif land == "USA" and ålder == "18-45" and budget == "20 000:- eller mer" and syssla == "Sol och bad":
    print("- Miami")
  elif land == "USA" and ålder == "18-45" and budget == "20 000:- eller mer" and syssla == "Aktiviteter":
    print("- New York")
  elif land == "Australien" and ålder == "18-45" and budget == "20 000:- eller mer" and syssla == "Sol och bad":
    print("- Gold Coast")
  elif land == "Australien" and ålder == "18-45" and budget == "20 000:- eller mer" and syssla == "Aktiviteter":
    print("- Sydney")
  elif land == "USA" and ålder == "46-65" and budget == "10-15 000:-" and syssla == "Sol och bad":
    print("- Hawaii")
  elif land == "USA" and ålder == "46-65" and budget == "10-15 000:-" and syssla == "Aktiviteter":
    print("- Las Vegas")
  elif land == "Australien" and ålder == "46-65" and budget == "10-15 000:-" and syssla == "Sol och bad":
    print("- Cairns")
  elif land == "Australien" and ålder == "46-65" and budget == "10-15 000:-" and syssla == "Aktiviteter":
    print("- Darwin")
  else:
    print(
      "- Tyvärr kunde vi inte hitta några passande resmål baserat på dina val."
    )


give_suggestions()
