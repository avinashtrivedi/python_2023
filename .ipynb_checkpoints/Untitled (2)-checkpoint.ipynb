# %%
from PIL import Image
import torch
from torch import nn
from torchvision.transforms import ToTensor
from torchvision import models
from torchvision import datasets
import torch.optim as optim

#from labels import labels

model = models.alexnet(pretrained=True)
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
# ...

# %%
# we will save the conv layer weights in this list
model_weights =[]
#we will save the 49 conv layers in this list
conv_layers = []

# get all the model children as list
model_children = list(model.children())

#counter to keep count of the conv layers
counter = 0

#append all the conv layers and their respective wights to the list
for i in range(len(model_children)):
    print(type(model_children[i]))
    if type(model_children[i]) == nn.Sequential:
        model_new_children = list(model_children[i].children())
        #print(model_new_children)
        for j in range(len(model_new_children)):        
            if type(model_new_children[j]) == nn.Conv2d:
                counter+=1
                model_weights.append(model_new_children[j].weight)
                conv_layers.append(model_new_children[j])
                
print(f"Total convolution layers: {counter}")
print(conv_layers)
# Out:
# <class 'torch.nn.modules.container.Sequential'>
# <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>
# <class 'torch.nn.modules.container.Sequential'>
# Total convolution layers: 5
# [Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2)), Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2)), Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))]

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=0., std=1.)
])

# %%
image = Image.open(str(r'C:\Users\ehsan\Documents\PhD Application\Univs\Western University\Stimuli Set\Stimuli Set\001.jpg'))
plt.imshow(image)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
image = torch.from_numpy(np.array(image)).long()
image = transform(image)
print(f"Image shape before: {image.shape}")
image = image.unsqueeze(0)
print(f"Image shape after: {image.shape}")
image = image.to(device)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [47], in <cell line: 2>()
#       1 image = torch.from_numpy(np.array(image)).long()
# ----> 2 image = transform(image)
#       3 print(f"Image shape before: {image.shape}")
#       4 image = image.unsqueeze(0)
#
# File ~/.cache\torch\hub\pytorch_vision_v0.10.0\torchvision\transforms\transforms.py:60, in Compose.__call__(self, img)
#      58 def __call__(self, img):
#      59     for t in self.transforms:
# ---> 60         img = t(img)
#      61     return img
#
# File ~/.cache\torch\hub\pytorch_vision_v0.10.0\torchvision\transforms\transforms.py:179, in ToPILImage.__call__(self, pic)
#     170 def __call__(self, pic):
#     171     """
#     172     Args:
#     173         pic (Tensor or numpy.ndarray): Image to be converted to PIL Image.
#    (...)
#     177
#     178     """
# ...

# %%
def conv_featuremap_extraction(image):
    outputs = []
    names = []
    for layer in conv_layers[0:]:
        image = layer(image)
        outputsuts.append(image)
        names.append(str(layer))
    print(len(outputs))
    #print feature_maps
    for feature_map in outputs:
        print(feature_map)

# %%
def fc_featuremap_extraction(image):
    outputs = []
    names = []
    for layer in fc_layers[0:]:
        image = layer(image)
        outputsuts.append(image)
        names.append(str(layer))
    print(len(outputs))
    #print feature_maps
    for feature_map in outputs:
        print(feature_map)

# %%
processed = []
for feature_map in outputs:
    feature_map = feature_map.squeeze(0)
    gray_scale = torch.sum(feature_map,0)
    gray_scale = gray_scale / feature_map.shape[0]
    processed.append(gray_scale.data.cpu().numpy())
for fm in processed:
    print(fm.shape)

# %%
vector_fmaps = []
image_index = 0

for image in images:
    transformed_image = transform(image)
    conv_features = conv_featuremap_extraction(image)
    fc_features = fc_featuremap_extraction(image)
    vector_fmaps[image_index] = concatenate(conv and fc)
    image_index+=1

# %%
n = 156
m = 156
dist = [0] * n
for x in range (n):
    dist1[x] = [0] * m    
    
for i in range(156):
    for j in range(156):
        dist1[i,j] = numpy.linalg.norm(vector_fmaps[i]-vector_fmaps[j])

# %%
def transform(img):
    img = img.resize((256, 256)).convert('RGB')
    tensor = ToTensor()(img)
    return tensor

train_data = 
    transform = transform,
)
# Out:
# ...
# 9913344it [00:02, 3512190.36it/s]
# Extracting data\MNIST\raw\train-images-idx3-ubyte.gz to data\MNIST\raw
#
# ...
# 29696it [00:00, 7421441.43it/s]
# Extracting data\MNIST\raw\train-labels-idx1-ubyte.gz to data\MNIST\raw
#
# ...
# 1649664it [00:00, 2858634.09it/s]
# Extracting data\MNIST\raw\t10k-images-idx3-ubyte.gz to data\MNIST\raw
#
# ...
# 5120it [00:00, 5119150.53it/s]
# Extracting data\MNIST\raw\t10k-labels-idx1-ubyte.gz to data\MNIST\raw
# ...

# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import models, transforms, utils
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc
from PIL import Image
import json
# %matplotlib inline

# %%
model = models.resnet18(pretrained=True)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# we will save the conv layer weights in this list
model_weights =[]
#we will save the 49 conv layers in this list
conv_layers = []
# get all the model children as list
model_children = list(model.children())
#counter to keep count of the conv layers
counter = 0
#append all the conv layers and their respective wights to the list
for i in range(len(model_children)):
    if type(model_children[i]) == nn.Conv2d:
        counter+=1
        model_weights.append(model_children[i].weight)
        conv_layers.append(model_children[i])
    elif type(model_children[i]) == nn.Sequential:
        for j in range(len(model_children[i])):
            for child in model_children[i][j].children():
                if type(child) == nn.Conv2d:
                    counter+=1
                    model_weights.append(child.weight)
                    conv_layers.append(child)
print(f"Total convolution layers: {counter}")
print("conv_layers")
# Out:
# Total convolution layers: 17
# conv_layers
