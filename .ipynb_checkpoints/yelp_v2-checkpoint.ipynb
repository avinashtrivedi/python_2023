# %% [markdown]
# # Q1,2

# %%
# import libraries
import pandas as pd
import numpy as np
import string
import textdistance
from tqdm.notebook import tqdm
tqdm.pandas()

# ignore warnings
import warnings
warnings.filterwarnings('ignore')


# load the dataset
df = pd.read_csv(r"D:\OneDrive - NITT\Custom_Download\yelp.csv",
                 delimiter='\t',
                header=None)

# %% [markdown]
# # Q3

# %%
# ignore all punctuation !"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
def clean(x):
    return x.translate(str.maketrans('', '', string.punctuation)).lower()

# %%
# clean the dataset and store it in clean_text column
df['clean_text'] = df[0].progress_apply(clean)
# Out:
#   0%|          | 0/15000 [00:00<?, ?it/s]

# %%
df
# Out:
#                                                        0  \
# 0      I got 'new' tires from them and within two wee...
# 1      Don't waste your time.  We had two different p...
# 2      All I can say is the worst! We were the only 2...
# 3      I have been to this restaurant twice and was d...
# 4      Food was NOT GOOD at all! My husband & I ate h...
# ...                                                  ...
# 14995  We only went one day for breakfast one day and...
# 14996  I am not embarrassed to say I LOVE buffets. I ...
# 14997  This buffet was so so on a Saturday evening. I...
# 14998  This was our next destination for our \"Buffet...
# 14999  Only reason why we went here was because we wa...
#
#                                               clean_text
# 0      i got new tires from them and within two weeks...
# 1      dont waste your time  we had two different peo...
# 2      all i can say is the worst we were the only 2 ...
# 3      i have been to this restaurant twice and was d...
# 4      food was not good at all my husband  i ate her...
# ...                                                  ...
# 14995  we only went one day for breakfast one day and...
# 14996  i am not embarrassed to say i love buffets i a...
# 14997  this buffet was so so on a saturday evening i ...
# 14998  this was our next destination for our buffets ...
# 14999  only reason why we went here was because we wa...
#
# [15000 rows x 2 columns]

# %%
# pip install -q transformers

# %% [markdown]
# # Q4

# %%
# import DistilBertTokenizer and create tokenizer object
from transformers import DistilBertTokenizer
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")

# %%
# function to get tokens from a given text
def get_tokens(x):
    return tokenizer.tokenize(x)

# %%
# get tokens for each lines
df['tokens'] = df['clean_text'].progress_apply(get_tokens)
# Out:
#   0%|          | 0/15000 [00:00<?, ?it/s]

# %% [markdown]
# # Q5

# %%
# Now tokens column is our corpus for training word2vec model
corpus = df['tokens']

# %%
corpus
# Out:
# 0        [i, got, new, tires, from, them, and, within, ...
# 1        [don, ##t, waste, your, time, we, had, two, di...
# 2        [all, i, can, say, is, the, worst, we, were, t...
# 3        [i, have, been, to, this, restaurant, twice, a...
# 4        [food, was, not, good, at, all, my, husband, i...
#                                ...
# 14995    [we, only, went, one, day, for, breakfast, one...
# 14996    [i, am, not, embarrassed, to, say, i, love, bu...
# 14997    [this, buffet, was, so, so, on, a, saturday, e...
# 14998    [this, was, our, next, destination, for, our, ...
# 14999    [only, reason, why, we, went, here, was, becau...
# Name: tokens, Length: 15000, dtype: object

# %%
# import Word2Vec
from gensim.models import Word2Vec

# %%
# Train Word2Vec Model on corpus
model = Word2Vec(corpus, 
                 min_count=1,          # word frequency
                 vector_size=200,      # dimention of word embeddings
                 workers=8,            # Number of processors
                 sg=1                  # 1 for skip-gram
                )

# %%
model.wv['this'] #check embedding for 'this'
# Out:
#       dtype=float32)

# %%
# pip install textdistance

# %%
# get all words for which model is having embedding.
all_word2vec_vocab = set(model.wv.key_to_index)

# %%
all_word2vec_vocab
# Out:
# {'soto',
#  'start',
#  '##gm',
#  'grandparents',
#  'used',
#  '##oid',
#  'denying',
#  'spirits',
#  'driving',
#  'differential',
#  'denise',
#  'viewpoint',
#  'royalty',
#  'agent',
#  '##sty',
#  '##icia',
#  '##47',
#  'prank',
#  'sweep',
#  'trivial',
#  'swung',
#  'kali',
#  'rests',
#  '##icing',
#  '##vina',
#  'build',
#  'theory',
#  'anxiously',
#  'transmissions',
#  'assistant',
#  'wards',
#  'nightclub',
#  '##less',
#  'pleasantly',
#  'affiliated',
#  'unfortunately',
#  '##bolt',
#  'hurriedly',
#  'like',
#  'emperor',
#  'join',
#  'novelty',
#  'rogers',
#  'old',
#  'variance',
#  'steamer',
#  '##phile',
#  'verse',
#  '##bury',
#  'ramsey',
#  'deafening',
#  'chesapeake',
#  'while',
#  'idea',
#  'jim',
#  'pg',
#  'spread',
#  'continue',
#  '##mark',
#  'beau',
#  'eponymous',
#  'alien',
#  'humiliated',
#  '##zard',
#  'fx',
#  'lawyer',
#  '##gence',
#  'inspiring',
#  'duplicate',
#  'finest',
#  'chinatown',
#  'posse',
#  'mace',
#  'afi',
#  'prison',
#  'stiff',
#  'pines',
#  'dreams',
#  'instincts',
#  'buried',
#  'much',
#  'manly',
#  'dying',
#  'shown',
#  'reversed',
#  'capacity',
#  'stranded',
#  'arguably',
#  'caring',
#  'tuscany',
#  '##kis',
#  'double',
#  'tori',
#  'maris',
#  'amusing',
#  'nods',
#  'remaining',
#  '##ilo',
#  'mastering',
#  'retrieve',
#  'complications',
#  'feather',
#  'intra',
#  'recall',
#  '##hai',
#  'relying',
#  'jumping',
#  'sunrise',
#  '##27',
#  'thigh',
#  '##pins',
#  'promenade',
#  '##app',
#  '##vos',
#  'seemingly',
#  'alessandro',
#  'spacious',
#  '##ards',
#  'grave',
#  'around',
#  'narrows',
#  'moonlight',
#  'pre',
#  '##liest',
#  'trump',
#  'examinations',
#  'nobody',
#  'painting',
#  '##lized',
#  'sparsely',
#  'truck',
#  'forgiveness',
#  'knives',
#  '##fen',
#  'goat',
#  '146',
#  'politically',
#  'parked',
#  'treasures',
#  'teenager',
#  'cares',
#  'advising',
#  'emergency',
#  '##otto',
#  '##mad',
#  'brightness',
#  'continues',
#  'failing',
#  'plastics',
#  'canadian',
#  'godzilla',
#  'horrified',
#  'campaign',
#  'evaluation',
#  '##tty',
#  'dinosaur',
#  'blossom',
#  'academics',
#  'implementing',
#  'bulb',
#  'groom',
#  'spec',
#  'competent',
#  'connected',
#  '##gra',
#  'enjoyment',
#  'pirate',
#  'ira',
#  'reasonable',
#  '##sha',
#  'commonplace',
#  'commenting',
#  'hardy',
#  'que',
#  '##ami',
#  'brooklyn',
#  '##3',
#  '##fles',
#  'afford',
#  'mit',
#  'laundering',
#  'wallet',
#  'bored',
#  '##lian',
#  'sanctuary',
#  'succeed',
#  'font',
#  'bothered',
#  'breast',
#  'windshield',
#  'heavy',
#  'plant',
#  'publicly',
#  'emissions',
#  'management',
#  'gall',
#  '##rase',
#  '##gic',
#  'out',
#  'pregnant',
#  'strictly',
#  'ignorance',
#  'pay',
#  'rotated',
#  'mayhem',
#  'ether',
#  'woods',
#  'helpful',
#  'choked',
#  'violinist',
#  'audience',
#  'filling',
#  'dramas',
#  'signature',
#  'thornton',
#  '##xes',
#  'kevin',
#  'swapped',
#  '##burgh',
#  'cheating',
#  'documentation',
#  'over',
#  '740',
#  'money',
#  'tara',
#  'hinted',
#  'actual',
#  '##n',
#  '##70',
#  '##urance',
#  'mechanically',
#  'fighting',
#  'mystery',
#  'baja',
#  '70s',
#  'divorced',
#  'sour',
#  '##proof',
#  '##ony',
#  'penalty',
#  'shower',
#  'bananas',
#  'indifferent',
#  'seductive',
#  'modes',
#  'aide',
#  '##boot',
#  '##rut',
#  'opener',
#  'ireland',
#  'upheld',
#  'perpetual',
#  'cost',
#  'admiration',
#  'sarajevo',
#  'providence',
#  '##ama',
#  '##iring',
#  'vietnamese',
#  'terminals',
#  'nat',
#  'acquired',
#  'speedy',
#  'fetch',
#  'fathers',
#  '##ef',
#  'nancy',
#  '##iji',
#  'leading',
#  'chicks',
#  'sufficient',
#  'institute',
#  'nc',
#  'eva',
#  '##ggs',
#  'belongings',
#  'humor',
#  'mocking',
#  'gala',
#  'catalina',
#  'hardest',
#  'tram',
#  '##kers',
#  'discount',
#  'export',
#  'skipped',
#  'graz',
#  'mozart',
#  'scares',
#  'grind',
#  'newcomers',
#  '##bar',
#  '##cer',
#  'document',
#  'misunderstanding',
#  '##cera',
#  'somme',
#  'dust',
#  'umm',
#  'theater',
#  'patriotic',
#  '##rs',
#  'wolves',
#  'real',
#  '##ax',
#  'pursued',
#  'spanning',
#  'sources',
#  '##itte',
#  'audible',
#  'slab',
#  '##thed',
#  'cathy',
#  'ek',
#  'monster',
#  'telephone',
#  'persuaded',
#  'nbc',
#  'tugs',
#  'dawson',
#  'starters',
#  'broadway',
#  '##ggle',
#  'll',
#  'contest',
#  'starred',
#  'encompass',
#  '7th',
#  'rye',
#  'lava',
#  'govt',
#  'carved',
#  'heal',
#  'nine',
#  'dip',
#  'preliminary',
#  'withdrawal',
#  'methods',
#  'huts',
#  'hastily',
#  'turner',
#  'biker',
#  'pun',
#  'tall',
#  '##te',
#  'seminar',
#  '##oles',
#  'indifference',
#  '##cuit',
#  '1950',
#  '##gging',
#  'opaque',
#  'poly',
#  'warmed',
#  'feathers',
#  'media',
#  'news',
#  '##tered',
#  'martyr',
#  'proof',
#  'closer',
#  '##ative',
#  'professor',
#  'georgie',
#  'clear',
#  'stopping',
#  '##eh',
#  'unconscious',
#  '##led',
#  'spy',
#  'possession',
#  'hiding',
#  'cheer',
#  '##rade',
#  'indicated',
#  'sen',
#  'arenas',
#  'sterling',
#  'rush',
#  '##pired',
#  'coca',
#  'cardinals',
#  'frustrating',
#  'lakes',
#  'torres',
#  '##zy',
#  'reviewed',
#  'discussed',
#  'died',
#  'logo',
#  'roof',
#  'minor',
#  'philadelphia',
#  'mechanisms',
#  'melted',
#  '##used',
#  '##end',
#  'bazaar',
#  'ryan',
#  'cake',
#  '##lee',
#  '##kan',
#  '##ray',
#  '##cide',
#  'absorbing',
#  '##writing',
#  'marble',
#  'raced',
#  'foraging',
#  'vest',
#  'headache',
#  'preference',
#  'catastrophic',
#  '##ech',
#  'mar',
#  '##lers',
#  'nude',
#  'goin',
#  'darkly',
#  'mcqueen',
#  '255',
#  'rocks',
#  'europe',
#  'apprentice',
#  'given',
#  'resembled',
#  'damages',
#  '##uez',
#  'purposely',
#  'interactions',
#  '##wich',
#  'wee',
#  'hanoi',
#  'optimistic',
#  'mysore',
#  'ripped',
#  'patients',
#  'phelps',
#  'tape',
#  '##kus',
#  'determines',
#  'cory',
#  'haunt',
#  '##rat',
#  'passengers',
#  'quiet',
#  'intervals',
#  'sr',
#  'neat',
#  'vaccines',
#  'caine',
#  'boxing',
#  'pledged',
#  'undergone',
#  'attached',
#  '31st',
#  'simpson',
#  'as',
#  'approve',
#  'officers',
#  '##ount',
#  'contrast',
#  '##cana',
#  'cheering',
#  'ships',
#  'stripped',
#  'madeleine',
#  'thousand',
#  'musician',
#  'pneumonia',
#  'employers',
#  '##24',
#  'witness',
#  'textbook',
#  '##do',
#  'necessarily',
#  'compensation',
#  'detected',
#  'tad',
#  '60',
#  '##sity',
#  'helicopters',
#  '129',
#  '630',
#  'ugly',
#  'irrelevant',
#  'unsuccessful',
#  'citing',
#  '##wad',
#  'woman',
#  'orleans',
#  '##istic',
#  'northwest',
#  'kerry',
#  'inlet',
#  '##iano',
#  'fish',
#  'pe',
#  'pauses',
#  'escalated',
#  '##tori',
#  'housemates',
#  'wondered',
#  '##war',
#  '##red',
#  'probable',
#  'use',
#  'teachings',
#  'layer',
#  'relation',
#  '216',
#  '##ners',
#  '##rrell',
#  'pierce',
#  'hp',
#  'vitamin',
#  'deployed',
#  '##nse',
#  'affiliation',
#  'shelf',
#  'dried',
#  'miracle',
#  '52',
#  'facade',
#  'wyatt',
#  'booth',
#  'hove',
#  '##wn',
#  '337',
#  'hamilton',
#  'exhibitions',
#  'lindsey',
#  'protocol',
#  'rann',
#  'nirvana',
#  'breathe',
#  'me',
#  'ze',
#  '##houses',
#  'attributed',
#  '##cie',
#  '##aries',
#  'quieter',
#  '##abe',
#  'thank',
#  'prevalent',
#  'toilet',
#  'operations',
#  'internally',
#  'originally',
#  '##tro',
#  'jacobs',
#  'friend',
#  'osborn',
#  'defect',
#  'allowed',
#  '##rite',
#  'wade',
#  'sacrificed',
#  'commune',
#  'nestled',
#  'dillon',
#  'memo',
#  '39th',
#  'judges',
#  'illustrated',
#  'gravel',
#  'vicki',
#  '##ytic',
#  'hide',
#  'costly',
#  'apologetic',
#  '##layer',
#  '##atable',
#  'breaks',
#  'spiral',
#  'india',
#  'strangers',
#  'becca',
#  '##hr',
#  '##fort',
#  'succumbed',
#  'relative',
#  'disposed',
#  'buds',
#  'tackle',
#  'keeping',
#  'louisiana',
#  '##esthesia',
#  'systems',
#  '##17',
#  'mainline',
#  'locals',
#  'rattling',
#  'simplicity',
#  'beams',
#  '##yah',
#  'let',
#  'asahi',
#  'agents',
#  '##hen',
#  'pages',
#  'largely',
#  'asleep',
#  '##aur',
#  'absence',
#  'them',
#  'flavor',
#  'fiance',
#  '##beat',
#  'rs',
#  '##fra',
#  '##izer',
#  'professionally',
#  'mel',
#  'edge',
#  'underlying',
#  'styx',
#  'played',
#  '##ook',
#  'soccer',
#  'allegro',
#  '##cam',
#  '##rea',
#  '##oms',
#  '##gai',
#  'conferences',
#  'political',
#  'immigrants',
#  '##ety',
#  'melissa',
#  'www',
#  'recommend',
#  'trace',
#  'bran',
#  'takes',
#  '##tablished',
#  'casino',
#  '##hom',
#  'included',
#  '1860',
#  'already',
#  'writ',
#  'settled',
#  'income',
#  'coverage',
#  'stem',
#  'baffled',
#  '##tions',
#  'strands',
#  'assisted',
#  'hawthorn',
#  'nominate',
#  'authors',
#  'penn',
#  'blake',
#  'regional',
#  '##tf',
#  'jo',
#  'dod',
#  'midwest',
#  'blizzard',
#  'jerusalem',
#  '247',
#  'fleet',
#  'wonderful',
#  'controllers',
#  'emilia',
#  'full',
#  'simulator',
#  'decides',
#  'lilly',
#  'therapy',
#  '##wind',
#  'flint',
#  'sexuality',
#  '221',
#  '26th',
#  'humanity',
#  'ecstasy',
#  'in',
#  '##lla',
#  'arranging',
#  'doctor',
#  'deliberate',
#  'gigantic',
#  'cocaine',
#  'conscious',
#  'tail',
#  'humidity',
#  'considered',
#  'can',
#  'space',
#  'paste',
#  '##lak',
#  'faa',
#  'credited',
#  'ceiling',
#  'op',
#  'intensive',
#  'stove',
#  '##rica',
#  'priorities',
#  'cord',
#  'paid',
#  'lastly',
#  'incredibly',
#  'geo',
#  'fridge',
#  '##mies',
#  'purchased',
#  'windows',
#  'solutions',
#  'admitting',
#  '##ammed',
#  '341',
#  'inspections',
#  '##hardt',
#  'labelled',
#  '##xi',
#  '##dee',
#  '##ario',
#  '##adia',
#  'rolled',
#  'shelly',
#  '##boys',
#  'rec',
#  '##hill',
#  'result',
#  'bile',
#  'ask',
#  'bundle',
#  'conclude',
#  '##rford',
#  'adjusted',
#  'crescent',
#  'diversion',
#  'sega',
#  'understanding',
#  'shivers',
#  'niece',
#  'frowns',
#  'needing',
#  'weights',
#  'posing',
#  'foothills',
#  'kidnap',
#  'comfort',
#  'renewal',
#  'leveled',
#  '##mill',
#  'starved',
#  'recipient',
#  'disrupt',
#  'revenues',
#  'cb',
#  'committee',
#  'daylight',
#  'worms',
#  'blankly',
#  'educational',
#  'protector',
#  'turkish',
#  'insistent',
#  'conditions',
#  'afforded',
#  'ba',
#  'printers',
#  'bulbs',
#  'intriguing',
#  'circled',
#  'cyber',
#  'card',
#  'vicky',
#  'santiago',
#  '##nts',
#  'proved',
#  'adjective',
#  'cycles',
#  '600',
#  'dread',
#  'checking',
#  '##bour',
#  '##r',
#  'seeing',
#  '##sho',
#  'pussy',
#  'environmentally',
#  '##pan',
#  'helium',
#  'pa',
#  'serves',
#  'saved',
#  'barbecue',
#  '##man',
#  'minister',
#  'tried',
#  'pitchfork',
#  'granddaughter',
#  'tends',
#  '##bson',
#  '##dda',
#  'humanities',
#  'weaknesses',
#  '##aa',
#  'pilgrimage',
#  '##sons',
#  'tiled',
#  'stand',
#  'afb',
#  'inner',
#  '##unk',
#  'nowhere',
#  'spare',
#  '##pm',
#  'sports',
#  '300',
#  'hasty',
#  'campus',
#  'courtyard',
#  'anger',
#  'undergoing',
#  'hopeless',
#  'usher',
#  'optional',
#  'mars',
#  '##oche',
#  '##bird',
#  'wei',
#  'una',
#  'elongated',
#  'agree',
#  '##car',
#  'darker',
#  '##din',
#  'av',
#  'bk',
#  'fireworks',
#  '##hood',
#  'orphanage',
#  'slope',
#  'solving',
#  'plural',
#  'invited',
#  'mats',
#  'before',
#  'observations',
#  'shark',
#  'grateful',
#  'mustache',
#  'a2',
#  'irritation',
#  'ut',
#  'demonstrating',
#  'bouncing',
#  '##tam',
#  '##kling',
#  'quality',
#  'giggling',
#  'dreaming',
#  'abandon',
#  'elliptical',
#  '##ea',
#  'games',
#  'mt',
#  'advertised',
#  'stainless',
#  'este',
#  'hip',
#  '##ging',
#  'singing',
#  'lurking',
#  'ban',
#  'litter',
#  'tony',
#  'mummy',
#  'presbyterian',
#  'sui',
#  'revenge',
#  'hates',
#  '##sable',
#  'participating',
#  'duval',
#  '##ps',
#  'delivering',
#  'recover',
#  '##woods',
#  '##tique',
#  '##ein',
#  '##ians',
#  'sank',
#  'hung',
#  'able',
#  'congestion',
#  '##lence',
#  'weak',
#  'disclosure',
#  '##genesis',
#  'malaysian',
#  'mike',
#  'abnormal',
#  'wine',
#  'joins',
#  'yukon',
#  '##ever',
#  'cheers',
#  'compliant',
#  'rippled',
#  'tribune',
#  '##ador',
#  'designs',
#  '##forms',
#  'glowing',
#  'edit',
#  'stained',
#  'wounds',
#  '##onus',
#  'displeasure',
#  'oder',
#  'silky',
#  'completing',
#  'walls',
#  'disorders',
#  'jerked',
#  'lou',
#  'ry',
#  'controls',
#  '##thest',
#  '##hum',
#  '##60',
#  'expressing',
#  '48',
#  'insulting',
#  'reflex',
#  'dramatic',
#  'television',
#  'stubble',
#  'shatter',
#  '##garh',
#  'households',
#  'nouveau',
#  '##fera',
#  'fortunately',
#  'gears',
#  'made',
#  'credibility',
#  'stormy',
#  'stumbling',
#  'optimal',
#  'ou',
#  'choreography',
#  'estimated',
#  '##aking',
#  'steele',
#  'cosmos',
#  '##uy',
#  'swaying',
#  '1831',
#  '##bro',
#  '##cs',
#  'disappointed',
#  'raided',
#  '##kins',
#  'tuned',
#  'gorge',
#  'transitioned',
#  'thief',
#  '##parts',
#  'dependent',
#  'sorting',
#  '##chang',
#  '##ip',
#  '##bis',
#  'picnic',
#  '351',
#  '##ishly',
#  '##els',
#  'imaginative',
#  'critics',
#  'stump',
#  'possibility',
#  'joined',
#  '205',
#  'rolls',
#  'couch',
#  '##eak',
#  'endure',
#  '##wyn',
#  '##heimer',
#  'form',
#  'discs',
#  'smash',
#  'traders',
#  '##mans',
#  'person',
#  '##aghan',
#  'processes',
#  'cary',
#  '##pro',
#  'darts',
#  ...}

# %% [markdown]
# # Q 6-7

# %%
# get embedding of any word

def embed(word):
    
    # get tokens
    tokens = get_tokens(word.lower())
    
    print('tokens',tokens)
    # initialize it with 0, as we need to do Average.
    embedding = np.zeros((200))
    
    # total number of token present in word
    n = len(tokens)
    
    # for each token get their embedding 
    for token in tokens:
        
        # if token in present in word2vec model then take its embedding from the model itself
        if token in all_word2vec_vocab:
            embedding =  embedding + model.wv.get_vector(token)
            
        # if not present, get the closed word in word2vec model using levenshtein 
        #and get their embedding
        else:
            key_in_model = sorted([(textdistance.levenshtein.normalized_distance(e,token), e) for e in all_word2vec_vocab],reverse=True)[0][1]
            embedding =  embedding + model.wv.get_vector(key_in_model)
            print('Missing:',token,'was replaced by:',key_in_model)
    # return average
    return embedding/n

# %%
embed('capturing')
# Out:
# tokens ['capturing']
# array([ 0.01319182, -0.03086699,  0.01386468,  0.00400418,  0.05156008,
#        -0.02781689,  0.00263223,  0.1186272 ,  0.00237181,  0.04792605,
#        -0.01278259, -0.07234085,  0.01668744,  0.06755218, -0.05790672,
#        -0.02472644, -0.02157385, -0.02039355,  0.00577635, -0.11322032,
#         0.03412848, -0.02939377,  0.0566329 ,  0.01762407,  0.01123586,
#        -0.03570064,  0.01979497, -0.06237185, -0.08609715,  0.0027248 ,
#         0.05720227,  0.02175297,  0.04432205,  0.0334942 ,  0.03129559,
#         0.02755326,  0.02684237,  0.00516881, -0.02638847, -0.04504759,
#        -0.03101944, -0.03051468,  0.00969181,  0.00170613,  0.03911392,
#         0.01811376,  0.00751254, -0.02651414,  0.08815496,  0.08694479,
#         0.02697583,  0.0027897 ,  0.06679496, -0.08807959, -0.01598597,
#        -0.02504161,  0.00776912, -0.03141798, -0.09840126,  0.00372895,
#        -0.04001177,  0.02679459, -0.03950952, -0.0100818 , -0.10573756,
#         0.01116486, -0.0094537 ,  0.14020903, -0.05065979,  0.05594513,
#         0.02061557, -0.01426807,  0.05790052,  0.01213234, -0.01068258,
#         0.01665612,  0.06227306, -0.01364073, -0.08791224, -0.02477942,
#        -0.03323577, -0.05232282, -0.04960292,  0.0842078 , -0.07087555,
#        -0.01958935, -0.01614351,  0.08566745, -0.01901434,  0.0123522 ,
#         0.02687987,  0.02763287,  0.04999708,  0.07197075,  0.08269229,
#         0.04871759,  0.03575267, -0.08017416,  0.06085831,  0.02857535,
#        -0.07400066,  0.06502136,  0.00417477, -0.03760775, -0.07289686,
#        -0.08194037,  0.04073736,  0.05714586, -0.04040091, -0.05139454,
