# %%
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
# !pip install mlxtend

# %%
# read csv file
df = pd.read_csv("D:\OneDrive - NITT\Custom_Download\Trial_SW.csv")

# %%
df
# Out:
#         smlt   asn    sd   t2m   skt   sp  msl  ssrd strd  u10  v10  tp  tcc
# 0       strd   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN NaN  NaN
# 1         sp   msl  strd   u10   NaN  NaN  NaN   NaN  NaN  NaN  NaN NaN  NaN
# 2       strd   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN NaN  NaN
# 3        msl  strd   asn   v10   u10  NaN  NaN   NaN  NaN  NaN  NaN NaN  NaN
# 4       strd   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN NaN  NaN
# ...      ...   ...   ...   ...   ...  ...  ...   ...  ...  ...  ...  ..  ...
# 223867  smlt   u10  si10   NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN NaN  NaN
# 223868  smlt    tp   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN  NaN NaN  NaN
# 223869   asn   msl   v10  strd   NaN  NaN  NaN   NaN  NaN  NaN  NaN NaN  NaN
# 223870   asn   msl   skt   v10  strd  NaN  NaN   NaN  NaN  NaN  NaN NaN  NaN
# 223871    tp    sp  ssrd   u10   asn  skt  v10  strd  NaN  NaN  NaN NaN  NaN
#
# [223872 rows x 13 columns]

# %%
x = df[df.columns].progress_apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
# Out:
#   0%|          | 0/223872 [00:00<?, ?it/s]

# %%
data = pd.DataFrame([])

# %%
data['Transaction'] = x

# %%
data.reset_index(inplace=True)

# %%
data.rename(columns={'index':'ID'},inplace=True)

# %%
data
# Out:
#             ID                      Transaction
# 0            0                             strd
# 1            1                  sp,msl,strd,u10
# 2            2                             strd
# 3            3             msl,strd,asn,v10,u10
# 4            4                             strd
# ...        ...                              ...
# 223867  223867                    smlt,u10,si10
# 223868  223868                          smlt,tp
# 223869  223869                 asn,msl,v10,strd
# 223870  223870             asn,msl,skt,v10,strd
# 223871  223871  tp,sp,ssrd,u10,asn,skt,v10,strd
#
# [223872 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import association_rules, apriori
from mlxtend.preprocessing import TransactionEncoder

# get all the transcactions as a list
transcactions = list(data['Transaction'].apply(lambda x: sorted(x.split(','))))

# instantiate transcation encoder
encoder = TransactionEncoder().fit(transcactions)

onehot = encoder.transform(transcactions)

# convert one-hot encode data to DataFrame
onehot = pd.DataFrame(onehot, columns=encoder.columns_)
# compute frequent items using the Apriori algorithm - Get up to three items
frequent_itemsets = apriori(onehot, min_support = 0.001, max_len = 3, use_colnames=True)

# compute all association rules for frequent_itemsets
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
rules
# Out:
#      antecedents consequents  antecedent support  consequent support  \
# 0          (msl)       (asn)            0.201651            0.475236
# 1          (asn)       (msl)            0.475236            0.201651
# 2         (si10)       (asn)            0.088443            0.475236
# 3          (asn)      (si10)            0.475236            0.088443
# 4          (skt)       (asn)            0.060142            0.475236
# ...          ...         ...                 ...                 ...
# 1749   (tp, u10)       (v10)            0.159198            0.320755
# 1750  (v10, u10)        (tp)            0.168632            0.364387
# 1751        (tp)  (v10, u10)            0.364387            0.168632
# 1752       (v10)   (tp, u10)            0.320755            0.159198
# 1753       (u10)   (tp, v10)            0.340802            0.193396
#
#        support  confidence      lift  leverage  conviction  zhangs_metric
# 0     0.129717    0.643275  1.353591  0.033885    1.471060       0.327206
# 1     0.129717    0.272953  1.353591  0.033885    1.098071       0.497794
# 2     0.053066    0.600000  1.262531  0.011035    1.311910       0.228116
# 3     0.053066    0.111663  1.262531  0.011035    1.026138       0.396255
# 4     0.050708    0.843137  1.774145  0.022126    3.345371       0.464270
# ...        ...         ...       ...       ...         ...            ...
# 1749  0.076651    0.481481  1.501089  0.025587    1.309973       0.397022
# 1750  0.076651    0.454545  1.247426  0.015204    1.165291       0.238582
# 1751  0.076651    0.210356  1.247426  0.015204    1.052839       0.312059
# 1752  0.076651    0.238971  1.501089  0.025587    1.104822       0.491453
# 1753  0.076651    0.224913  1.162967  0.010741    1.040663       0.212577
#
# [1754 rows x 10 columns]

# %%
rules['lhs items'] = rules['antecedents'].apply(lambda x:len(x) )
rules[rules['lhs items']>1].sort_values('lift', ascending=False).head()
# Out:
#      antecedents consequents  antecedent support  consequent support  \
# 897   (t2m, skt)        (sd)            0.001179            0.036557
# 538    (sd, msl)       (t2m)            0.003538            0.020047
# 898    (sd, skt)       (t2m)            0.003538            0.020047
# 927  (t2m, smlt)        (sd)            0.007075            0.036557
# 874  (skt, smlt)        (sd)            0.007075            0.036557
#
#       support  confidence       lift  leverage  conviction  zhangs_metric  \
# 897  0.001179    1.000000  27.354839  0.001136         inf       0.964581
# 538  0.001179    0.333333  16.627451  0.001108    1.469929       0.943195
# 898  0.001179    0.333333  16.627451  0.001108    1.469929       0.943195
# 927  0.003538    0.500000  13.677419  0.003279    1.926887       0.933492
# 874  0.003538    0.500000  13.677419  0.003279    1.926887       0.933492
#
#      lhs items
# 897          2
# 538          2
# 898          2
# 927          2
# 874          2

# %%
rules['lift'].nlargest(n=10)
# Out:
# 897    27.354839
# 900    27.354839
# 538    16.627451
# 898    16.627451
# 539    16.627451
# 899    16.627451
# 875    13.677419
# 930    13.677419
# 874    13.677419
# 927    13.677419
# Name: lift, dtype: float64

# %%
top5 = rules.nlargest(n=50, columns=['lift'])

# %%
# top5 = top5.replace(float('inf'),0)

# %%
# Import seaborn under its standard alias
import seaborn as sns

# Replace frozen sets with strings
top5['antecedents_'] = top5['antecedents'].apply(lambda a: ','.join(list(a)))
top5['consequents_'] = top5['consequents'].apply(lambda a: ','.join(list(a)))

# Transform the DataFrame of rules into a matrix using the lift metric
pivot1 = top5[top5['lhs items']>1].pivot(index = 'antecedents_', 
                    columns = 'consequents_', values= 'lift')

# Generate a heatmap with annotations on and the colorbar off
sns.heatmap(pivot1, annot = True)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
# Import seaborn under its standard alias
import seaborn as sns

# Replace frozen sets with strings
rules['antecedents_'] = rules['antecedents'].apply(lambda a: ','.join(list(a)))
rules['consequents_'] = rules['consequents'].apply(lambda a: ','.join(list(a)))

# Transform the DataFrame of rules into a matrix using the lift metric
pivot = rules[rules['lhs items']>1].pivot(index = 'antecedents_', 
                    columns = 'consequents_', values= 'lift')

# Generate a heatmap with annotations on and the colorbar off
sns.heatmap(pivot, annot = True)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()
