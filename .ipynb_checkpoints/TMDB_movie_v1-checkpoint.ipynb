# %%
# tmdb_5000_movies
# tmdb_5000_credits

# %%
# jupyter notebook

# %%
import pandas as pd

# %%
df_movies = pd.read_csv(r"D:\OneDrive - NITT\Custom_Download\tmdb_5000_movies.csv")
df_credits = pd.read_csv(r"D:\OneDrive - NITT\Custom_Download\tmdb_5000_credits.csv")

# %%
df_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df_credits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
df_movies[:2].T
# Out:
#                                                                       0  \
# budget                                                        237000000
# genres                [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                    http://www.avatarmovie.com/
# id                                                                19995
# keywords              [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                    en
# original_title                                                   Avatar
# overview              In the 22nd century, a paraplegic Marine is di...
# popularity                                                   150.437577
# production_companies  [{"name": "Ingenious Film Partners", "id": 289...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2009-12-10
# ...

# %%
#Todo
# 0) go through pandas
# 
# 2) use the following columns:- revenue,runtime,vote_average,vote_count,original_language,budget,popularity

# %%
df_movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
data = df_movies[['revenue','runtime','vote_average','vote_count','original_language','budget','popularity']]

# %%
data
# Out:
#          revenue  runtime  vote_average  vote_count original_language  \
# 0     2787965087    162.0           7.2       11800                en
# 1      961000000    169.0           6.9        4500                en
# 2      880674609    148.0           6.3        4466                en
# 3     1084939099    165.0           7.6        9106                en
# 4      284139100    132.0           6.1        2124                en
# ...          ...      ...           ...         ...               ...
# 4798     2040920     81.0           6.6         238                es
# 4799           0     85.0           5.9           5                en
# 4800           0    120.0           7.0           6                en
# 4801           0     98.0           5.7           7                en
# 4802           0     90.0           6.3          16                en
#
#          budget  popularity
# 0     237000000  150.437577
# 1     300000000  139.082615
# 2     245000000  107.376788
# ...

# %%
# modify text into numeric i.e categorical to numeric column

# %%
data['original_language'].unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
data = pd.get_dummies(data)

# %%
data
# Out:
#          revenue  runtime  vote_average  vote_count     budget  popularity  \
# 0     2787965087    162.0           7.2       11800  237000000  150.437577
# 1      961000000    169.0           6.9        4500  300000000  139.082615
# 2      880674609    148.0           6.3        4466  245000000  107.376788
# 3     1084939099    165.0           7.6        9106  250000000  112.312950
# 4      284139100    132.0           6.1        2124  260000000   43.926995
# ...          ...      ...           ...         ...        ...         ...
# 4798     2040920     81.0           6.6         238     220000   14.269792
# 4799           0     85.0           5.9           5       9000    0.642552
# 4800           0    120.0           7.0           6          0    1.444476
# 4801           0     98.0           5.7           7          0    0.857008
# 4802           0     90.0           6.3          16          0    1.929883
#
# ...

# %%
data.dtypes
# Out:
# revenue                   int64
# runtime                 float64
# vote_average            float64
# vote_count                int64
# budget                    int64
# popularity              float64
# original_language_af      uint8
# original_language_ar      uint8
# original_language_cn      uint8
# original_language_cs      uint8
# original_language_da      uint8
# original_language_de      uint8
# original_language_el      uint8
# original_language_en      uint8
# original_language_es      uint8
# original_language_fa      uint8
# original_language_fr      uint8
# original_language_he      uint8
# original_language_hi      uint8
# original_language_hu      uint8
# original_language_id      uint8
# original_language_is      uint8
# original_language_it      uint8
# original_language_ja      uint8
# original_language_ko      uint8
# original_language_ky      uint8
# original_language_nb      uint8
# original_language_nl      uint8
# original_language_no      uint8
# ...

# %%
data.dropna(inplace=True)

# %%
X = data.drop('popularity',axis=1)

# %%
y = data['popularity']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train
# Out:
#         revenue  runtime  vote_average  vote_count    budget  \
# 2852   22939027     94.0           5.6         364  12000000
# 3263   74952305     92.0           6.7        2210   8000000
# 4579    5028948     91.0           7.8        1708    400000
# 1774    6673422    104.0           5.2         127  25000000
# 1957   34670720    119.0           7.0         257  14000000
# ...         ...      ...           ...         ...       ...
# 4428          0     87.0           5.7          92    950000
# 466   123729176     96.0           5.8         631  80000000
# 3093          0    104.0           6.8          37         0
# 3773    1919197     96.0           6.1          67         0
# 860    89519773    119.0           6.9         573  55000000
#
#       original_language_af  original_language_ar  original_language_cn  \
# 2852                     0                     0                     0
# 3263                     0                     0                     0
# ...

# %%
# Linear regression

from sklearn.linear_model import LinearRegression

# %%
reg_model = LinearRegression()

# %%
reg_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg_model.predict(X_test)

# %%
y_pred # predicted popularity
# Out:
# array([ 1.34490933e+01,  5.94656478e+00,  1.03318181e+01,  2.41620216e+01,
#         1.24173185e+02,  3.30523263e+01,  1.10539173e+01,  4.49585245e+01,
#         8.61893701e+00,  2.60762346e+01,  9.89931984e+00,  1.29696800e+00,
#         7.73163820e+00,  2.89125501e+01,  4.18039454e+01,  2.07528724e+01,
#         9.20729995e+00,  5.33186569e+01,  1.70325093e+01,  9.93424284e+00,
#         1.94420948e+01,  1.53676097e+01,  6.88935116e+00,  6.23703801e+01,
#         2.42507361e+01,  1.01798960e+01,  7.11598019e+00,  1.11505272e+01,
#         8.22939052e+00,  3.01962097e+01,  6.68894897e+00,  8.19076947e+00,
#         1.02160004e+02,  1.35307892e+01,  7.94810914e+00,  8.45807538e+00,
#         4.03413386e+01,  3.84363098e+01,  2.01147340e+01,  1.13879329e+01,
#         8.33229295e+01,  7.24111079e+01,  6.39151619e+00,  1.46037638e+02,
#         9.55097701e+00,  3.93421332e+01,  1.02595997e+01,  8.06644629e+00,
# ...

# %%
y_test # actual test popularity
# Out:
# 596     13.267631
# 4509     0.001586
# 3050     9.525626
# 2958    32.943848
# 8       98.885637
#           ...
# 198     39.448066
# 2422    32.746486
# 1485     7.339908
# 402     24.107835
# 2760    66.113340
# Name: popularity, Length: 961, dtype: float64

# %%
pd.DataFrame({'y_actual':y_test,'y_pred':y_pred})
# Out:
#        y_actual      y_pred
# 596   13.267631   13.449093
# 4509   0.001586    5.946565
# 3050   9.525626   10.331818
# 2958  32.943848   24.162022
# 8     98.885637  124.173185
# ...         ...         ...
# 198   39.448066   33.425347
# 2422  32.746486   51.387023
# 1485   7.339908    8.924504
# 402   24.107835   20.098091
# 2760  66.113340   59.902650
#
# [961 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test,y_pred)  #True returns MSE value, if False returns RMSE value.
mse
# Out:
# 500.2558481379296

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
rmse
# Out:
# 22.36639998162265
