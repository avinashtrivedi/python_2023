# %%
import datasets
import pandas as pd


train_df = pd.DataFrame({
     "label" : [1, 2, 3],
     "text" : ["apple", "pear", "strawberry"]
})

test_df = pd.DataFrame({
     "label" : [2, 2, 1],
     "text" : ["banana", "pear", "apple"]
})

train_dataset = datasets.Dataset.from_dict(train_df)
test_dataset = datasets.Dataset.from_dict(test_df)
my_dataset_dict = datasets.DatasetDict({"train":train_dataset,"test":test_dataset})

# %%
my_dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'text'],
#         num_rows: 3
#     })
#     test: Dataset({
#         features: ['label', 'text'],
#         num_rows: 3
#     })
# })

# %%
train_df
# Out:
#    label        text
# 0      1       apple
# 1      2        pear
# 2      3  strawberry

# %%
test_df
# Out:
#    label    text
# 0      2  banana
# 1      2    pear
# 2      1   apple

# %%
from datasets import load_dataset

# load the custom dataset
ds = load_dataset(r"D:\OneDrive - NITT\Custom_Download", data_dir="Birad_Train")
ds
# Out:
# Resolving data files:   0%|          | 0/489 [00:00<?, ?it/s]
# ...
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset imagefolder downloaded and prepared to C:/Users/avitr/.cache/huggingface/datasets/imagefolder/Custom_Download-4f98dd6892b7788f/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 489
#     })
# })

# %%
labels  = ds['train'].features['label']

# %%
labels.int2str(ds["train"][300]["label"])
# Out:
# 'b3'

# %%
ds['train'][400]#.features['image']
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  'label': 1}

# %%
D:\OneDrive - NITT\Custom_Download\Birad_Train\train

# %%
import os
path = r"D:\OneDrive - NITT\Custom_Download\Birad3\b3"

# %%
x = os.listdir(r'D:\OneDrive - NITT\Custom_Download\Birad3\b3')

# %%
all_img = [os.path.join(path,i) for i in x]

# %%
all_img
# Out:
# ['D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC003026_ CC_L.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC003026_ CC_R.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC003026_ MLO_L.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC003026_ MLO_R.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC009941_ CC_L.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC009941_ CC_R.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC009941_ MLO_L.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC009941_ MLO_R.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC010562_ CC_L.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC010562_ CC_R.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC010562_ MLO_L.jpg',
#  'D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC010562_ MLO_R.jpg',
# ...

# %%
from datasets import load_dataset, Image,Dataset
dataset = Dataset.from_dict({"image": all_img}).cast_column("image", Image())

# %%
Image(all_img[0])
# Out:
# Image(decode='D:\\OneDrive - NITT\\Custom_Download\\Birad3\\b3\\2013_BC003026_ CC_L.jpg', id=None)

# %%
Dataset.from_dict({"image": all_img})
# Out:
# Dataset({
#     features: ['image'],
#     num_rows: 387
# })

# %%
dataset
# Out:
# Dataset({
#     features: ['image'],
#     num_rows: 387
# })

# %%
dataset.features
# Out:
# {'image': Image(decode=True, id=None)}

# %%
my_dataset_dict  = datasets.DatasetDict({"train":dataset,"test":dataset})
my_dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image'],
#         num_rows: 387
#     })
#     test: Dataset({
#         features: ['image'],
#         num_rows: 387
#     })
# })

# %%
my_dataset_dict['train']['image']
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1267x578>,
# ...
