# %%
import pandas as pd

# %%
df = pd.read_excel('D:\OneDrive - NITT\Custom_Download\RAC.xlsx')

# %%
df
# Out:
#      NAR_ID Application Name  Asset ID   Due Date  Days  \
# 0  100256-1              abc    302511  5/31/2023    58
# 1  100679-1              xyz    302512  3/31/2023   363
# 2  101515-1              pqr    302513  7/31/2023   191
# 3  101614-1              tsh    302514  7/31/2023   303
# 4  102955-1             cdnc    302515  7/31/2023    88
# 5  103055-1             cvds    302516  7/31/2023    68
# 6  103955-1             tsdg    302517  7/31/2023    27
# 7  103956-1              uyr    302518  7/31/2023   -34
# 8  103959-1              lxy    302519  7/31/2023    -3
#
#            Due Date Bucket Assessment Status   Task Status  Assessment ID  \
# 0           Due in 60 days           Created  No Open Task            NaN
# 1         Due in > 90 days           Created  No Open Task            NaN
# 2         Due in > 90 days           Created  No Open Task            NaN
# 3         Due in > 90 days           Created  No Open Task            NaN
# 4   Due in  90 daysor less           Created  No Open Task            NaN
# 5  Due in  90 days or less       In Progress  No Open Task            NaN
# 6   Due in 30 days or less       In Progress  No Open Task            NaN
# 7                Past  Due       In Progress  No Open Task            NaN
# 8                 Past due       In Progress  No Open Task            NaN
#
#   Due Date RAV Sign Of Date
# 0   2022-05-31          NaT
# 1   2023-05-31          NaT
# 2   2022-06-30          NaT
# 3   2022-07-11          NaT
# 4   2022-05-31   2022-05-31
# 5   2023-05-31   2023-05-31
# 6   2022-06-30   2022-06-30
# 7   2022-07-11   2022-07-11
# 8          NaT          NaT

# %%
x = df.groupby('Due Date Bucket')['Due Date Bucket'].count()

# %%
x = pd.DataFrame(x)

# %%
x.columns = ['count']

# %%
x = x.reset_index()

# %%
x['percent'] = 1/x['count']*100

# %%
x
# Out:
#            Due Date Bucket  count     percent
# 0  Due in  90 days or less      1  100.000000
# 1   Due in  90 daysor less      1  100.000000
# 2   Due in 30 days or less      1  100.000000
# 3           Due in 60 days      1  100.000000
# 4         Due in > 90 days      3   33.333333
# 5                Past  Due      1  100.000000
# 6                 Past due      1  100.000000

# %%
x.drop('count',axis=1,inplace=True)

# %%
d = {}
for indx,line in x.iterrows():
    k = line['Due Date Bucket']
    v = line['percent']
    d[k] = v

# %%
df['percent'] = df['Due Date Bucket'].apply(lambda x:d[x])

# %%
df
# Out:
#      NAR_ID Application Name  Asset ID   Due Date  Days  \
# 0  100256-1              abc    302511  5/31/2023    58
# 1  100679-1              xyz    302512  3/31/2023   363
# 2  101515-1              pqr    302513  7/31/2023   191
# 3  101614-1              tsh    302514  7/31/2023   303
# 4  102955-1             cdnc    302515  7/31/2023    88
# 5  103055-1             cvds    302516  7/31/2023    68
# 6  103955-1             tsdg    302517  7/31/2023    27
# 7  103956-1              uyr    302518  7/31/2023   -34
# 8  103959-1              lxy    302519  7/31/2023    -3
#
#            Due Date Bucket Assessment Status   Task Status  Assessment ID  \
# 0           Due in 60 days           Created  No Open Task            NaN
# 1         Due in > 90 days           Created  No Open Task            NaN
# 2         Due in > 90 days           Created  No Open Task            NaN
# 3         Due in > 90 days           Created  No Open Task            NaN
# 4   Due in  90 daysor less           Created  No Open Task            NaN
# 5  Due in  90 days or less       In Progress  No Open Task            NaN
# 6   Due in 30 days or less       In Progress  No Open Task            NaN
# 7                Past  Due       In Progress  No Open Task            NaN
# 8                 Past due       In Progress  No Open Task            NaN
#
#   Due Date RAV Sign Of Date     percent
# 0   2022-05-31          NaT  100.000000
# 1   2023-05-31          NaT   33.333333
# 2   2022-06-30          NaT   33.333333
# 3   2022-07-11          NaT   33.333333
# 4   2022-05-31   2022-05-31  100.000000
# 5   2023-05-31   2023-05-31  100.000000
# 6   2022-06-30   2022-06-30  100.000000
# 7   2022-07-11   2022-07-11  100.000000
# 8          NaT          NaT  100.000000

# %%
df
# Out:
#      NAR_ID Application Name  Asset ID   Due Date  Days  \
# 0  100256-1              abc    302511  5/31/2023    58
# 1  100679-1              xyz    302512  3/31/2023   363
# 2  101515-1              pqr    302513  7/31/2023   191
# 3  101614-1              tsh    302514  7/31/2023   303
# 4  102955-1             cdnc    302515  7/31/2023    88
# 5  103055-1             cvds    302516  7/31/2023    68
# 6  103955-1             tsdg    302517  7/31/2023    27
# 7  103956-1              uyr    302518  7/31/2023   -34
# 8  103959-1              lxy    302519  7/31/2023    -3
#
#            Due Date Bucket Assessment Status   Task Status  Assessment ID  \
# 0           Due in 60 days           Created  No Open Task            NaN
# 1         Due in > 90 days           Created  No Open Task            NaN
# 2         Due in > 90 days           Created  No Open Task            NaN
# 3         Due in > 90 days           Created  No Open Task            NaN
# 4   Due in  90 daysor less           Created  No Open Task            NaN
# 5  Due in  90 days or less       In Progress  No Open Task            NaN
# 6   Due in 30 days or less       In Progress  No Open Task            NaN
# 7                Past  Due       In Progress  No Open Task            NaN
# 8                 Past due       In Progress  No Open Task            NaN
#
#   Due Date RAV Sign Of Date     percent
# 0   2022-05-31          NaT  100.000000
# 1   2023-05-31          NaT   33.333333
# 2   2022-06-30          NaT   33.333333
# 3   2022-07-11          NaT   33.333333
# 4   2022-05-31   2022-05-31  100.000000
# 5   2023-05-31   2023-05-31  100.000000
# 6   2022-06-30   2022-06-30  100.000000
# 7   2022-07-11   2022-07-11  100.000000
# 8          NaT          NaT  100.000000

# %%
df['Quarter'] = df['Due Date RAV'].apply(lambda x:(x.month-1)//3)

# %%
df
# Out:
#      NAR_ID Application Name  Asset ID   Due Date  Days  \
# 0  100256-1              abc    302511  5/31/2023    58
# 1  100679-1              xyz    302512  3/31/2023   363
# 2  101515-1              pqr    302513  7/31/2023   191
# 3  101614-1              tsh    302514  7/31/2023   303
# 4  102955-1             cdnc    302515  7/31/2023    88
# 5  103055-1             cvds    302516  7/31/2023    68
# 6  103955-1             tsdg    302517  7/31/2023    27
# 7  103956-1              uyr    302518  7/31/2023   -34
# 8  103959-1              lxy    302519  7/31/2023    -3
#
#            Due Date Bucket Assessment Status   Task Status  Assessment ID  \
# 0           Due in 60 days           Created  No Open Task            NaN
# 1         Due in > 90 days           Created  No Open Task            NaN
# 2         Due in > 90 days           Created  No Open Task            NaN
# 3         Due in > 90 days           Created  No Open Task            NaN
# 4   Due in  90 daysor less           Created  No Open Task            NaN
# 5  Due in  90 days or less       In Progress  No Open Task            NaN
# 6   Due in 30 days or less       In Progress  No Open Task            NaN
# 7                Past  Due       In Progress  No Open Task            NaN
# 8                 Past due       In Progress  No Open Task            NaN
#
#   Due Date RAV Sign Of Date     percent  Quarter
# 0   2022-05-31          NaT  100.000000      1.0
# 1   2023-05-31          NaT   33.333333      1.0
# 2   2022-06-30          NaT   33.333333      1.0
# 3   2022-07-11          NaT   33.333333      2.0
# 4   2022-05-31   2022-05-31  100.000000      1.0
# 5   2023-05-31   2023-05-31  100.000000      1.0
# 6   2022-06-30   2022-06-30  100.000000      1.0
# 7   2022-07-11   2022-07-11  100.000000      2.0
# 8          NaT          NaT  100.000000      NaN

# %%
df['Due Date RAV'] = df['Due Date RAV'].fillna(df['Due Date RAV'].mode()[0])

# %%
import matplotlib.pyplot as plt

# %%
y = df[['Due Date Bucket','percent']].drop_duplicates()

# %%
y
# Out:
#            Due Date Bucket     percent
# 0           Due in 60 days  100.000000
# 1         Due in > 90 days   33.333333
# 4   Due in  90 daysor less  100.000000
# 5  Due in  90 days or less  100.000000
# 6   Due in 30 days or less  100.000000
# 7                Past  Due  100.000000
# 8                 Past due  100.000000

# %%
plt.bar(y['Due Date Bucket'],y['percent'])
plt.xticks(rotation=90)
plt.show()

# %%
month = {5:'May',6:'June',7:'July'} # make it 1 to 12

# %%
df['month'] = df['Due Date RAV'].apply(lambda x:month[int(x.month)])

# %%
df['Year'] = df['Due Date RAV'].apply(lambda x:int(x.year))

# %%
df
# Out:
#      NAR_ID Application Name  Asset ID   Due Date  Days  \
# 0  100256-1              abc    302511  5/31/2023    58
# 1  100679-1              xyz    302512  3/31/2023   363
# 2  101515-1              pqr    302513  7/31/2023   191
# 3  101614-1              tsh    302514  7/31/2023   303
# 4  102955-1             cdnc    302515  7/31/2023    88
# 5  103055-1             cvds    302516  7/31/2023    68
# 6  103955-1             tsdg    302517  7/31/2023    27
# 7  103956-1              uyr    302518  7/31/2023   -34
# 8  103959-1              lxy    302519  7/31/2023    -3
#
#            Due Date Bucket Assessment Status   Task Status  Assessment ID  \
# 0           Due in 60 days           Created  No Open Task            NaN
# 1         Due in > 90 days           Created  No Open Task            NaN
# 2         Due in > 90 days           Created  No Open Task            NaN
# 3         Due in > 90 days           Created  No Open Task            NaN
# 4   Due in  90 daysor less           Created  No Open Task            NaN
# 5  Due in  90 days or less       In Progress  No Open Task            NaN
# 6   Due in 30 days or less       In Progress  No Open Task            NaN
# 7                Past  Due       In Progress  No Open Task            NaN
# 8                 Past due       In Progress  No Open Task            NaN
#
#   Due Date RAV Sign Of Date     percent  Quarter month  Year
# 0   2022-05-31          NaT  100.000000      1.0   May  2022
# 1   2023-05-31          NaT   33.333333      1.0   May  2023
# 2   2022-06-30          NaT   33.333333      1.0  June  2022
# 3   2022-07-11          NaT   33.333333      2.0  July  2022
# 4   2022-05-31   2022-05-31  100.000000      1.0   May  2022
# 5   2023-05-31   2023-05-31  100.000000      1.0   May  2023
# 6   2022-06-30   2022-06-30  100.000000      1.0  June  2022
# 7   2022-07-11   2022-07-11  100.000000      2.0  July  2022
# 8   2022-05-31          NaT  100.000000      NaN   May  2022

# %%
df[(df['month']=='June') & (df['Year']==2022)]
# Out:
#      NAR_ID Application Name  Asset ID   Due Date  Days  \
# 2  101515-1              pqr    302513  7/31/2023   191
# 6  103955-1             tsdg    302517  7/31/2023    27
#
#           Due Date Bucket Assessment Status   Task Status  Assessment ID  \
# 2        Due in > 90 days           Created  No Open Task            NaN
# 6  Due in 30 days or less       In Progress  No Open Task            NaN
#
#   Due Date RAV Sign Of Date     percent  Quarter month  Year
# 2   2022-06-30          NaT   33.333333      1.0  June  2022
# 6   2022-06-30   2022-06-30  100.000000      1.0  June  2022

# %%
z = df[['month','Year']]

# %%
z
# Out:
#   month  Year
# 0   May  2022
# 1   May  2023
# 2  June  2022
# 3  July  2022
# 4   May  2022
# 5   May  2023
# 6  June  2022
# 7  July  2022
# 8   May  2022

# %%
z = z.groupby(['Year','month'])['month'].count()

# %%
z = pd.DataFrame(z)
z.columns  = ['count']

# %%
z.reset_index(inplace=True)

# %%
z
# Out:
#    Year month  count
# 0  2022  July      2
# 1  2022  June      2
# 2  2022   May      3
# 3  2023   May      2

# %%
# z['yr_mnth'] = 
z['date_combined'] = z.apply(lambda x: str(x['Year'])+'-'+x['month'],axis=1)

# %%
z
# Out:
#    Year month  count date_combined
# 0  2022  July      2     2022-July
# 1  2022  June      2     2022-June
# 2  2022   May      3      2022-May
# 3  2023   May      2      2023-May

# %%
plt.bar(z['date_combined'],z['count'])
plt.show()

# %%
data = pd.read_excel('D:\OneDrive - NITT\Custom_Download\RAC1.xlsx')

# %%
data
# Out:
#      NAR ID  Application Name  Assmt ID(RAV) Assmt Due Date(RAV_CA)  \
# 0   100256-1              abc         321055              5/31/2023
# 1   100679-1              xyz         321056              3/31/2023
# 2   101515-1              pqr         321057              7/31/2023
# 3   101614-1              tsh         321059              7/31/2023
# 4   102955-1             cdnc         321058              7/31/2023
# 5   103055-1             cvds         321055              7/31/2023
# 6   103955-1             tsdg         321055              7/31/2023
# 7   103956-1              uyr         321055              7/31/2023
# 8   103959-1              lxy         321055              7/31/2023
# 9   103966-1              lmc         321055              5/31/2023
# 10  103963-1           casknc         321055              3/31/2023
# 11  104899-1              cnc         321055              7/31/2023
# 12  105117-1          cnksanc         321055              7/31/2023
# 13  106954-1            cnsac         321055              7/31/2023
# 14  105178-1              swd         321055              7/31/2023
# 15  106954-1               sx         321055              7/31/2023
# 16  110101-1             xnsn         321055              7/31/2023
#
#     # Days(RAV)          Due Date Bucket Assmt Status   Task Status  Assmt ID  \
# 0            58           Due in 60 days      Created  No Open Task    321055
# 1           363         Due in > 90 days      Created  No Open Task    321056
# 2           191         Due in > 90 days      Created  No Open Task    321057
# 3           303         Due in > 90 days      Created  No Open Task    321059
# 4            88  Due in  90 days or less      Created  No Open Task    321058
# 5            68  Due in  90 days or less      Created  No Open Task    321055
# 6            27   Due in 30 days or less      Created  No Open Task    321055
# 7           -34                Past  Due      Created  No Open Task    321055
# 8            -3                 Past due      Created  No Open Task    321055
# 9            37           Due in 60 days      Created  No Open Task    321055
# 10          111         Due in > 90 days      Created  No Open Task    321055
# 11           78  Due in  90 days or less      Created  No Open Task    321055
# 12          150         Due in > 90 days      Created  No Open Task    321055
# 13          131         Due in > 90 days      Created  No Open Task    321055
# 14          211         Due in > 90 days      Created  No Open Task    321055
# 15           45  Due in  90 days or less      Created  No Open Task    321055
# 16          100         Due in > 90 days      Created  No Open Task    321055
#
#    Due Date RAV Sign Of Date(RAV)  Sign_Of_Date_quarter Sign_Of_Date_Month  \
# 0    2022-05-31        2022-05-31                   NaN                May
# 1    2023-05-31        2023-05-31                   NaN               July
# 2    2022-06-30        2022-06-30                   NaN           November
# 3    2022-07-11        2022-07-11                   NaN               July
# 4    2022-05-31        2022-05-31                   NaN               July
# 5    2023-05-31        2023-05-31                   NaN               July
# 6    2022-06-30        2022-06-30                   NaN               June
# 7    2022-07-11        2022-07-11                   NaN               June
# 8    2022-05-12        2022-05-12                   NaN           December
# 9    2022-08-11        2022-08-11                   NaN               July
# 10   2022-09-10        2022-09-10                   NaN               July
# 11   2022-06-12        2022-06-12                   NaN               July
# 12   2022-07-11        2022-07-11                   NaN               July
# 13   2022-05-31        2022-05-31                   NaN           November
# 14   2023-05-31        2023-05-31                   NaN               July
# 15   2022-06-30        2022-06-30                   NaN              April
# 16   2022-07-11        2022-07-11                   NaN           December
#
#     Sign_Of_Date_Year
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN

# %%
import random

# %%
def plot_graph(df1,title,x,y):
    fig, ax = plt.subplots(figsize=(10, 6))
    colors = []
    for _ in range(len(df1)):
        random_color = (random.random(), random.random(), random.random())
        colors.append(random_color)

    bars = ax.bar(df1[x], df1[y], color=colors)

    # Add count and percentage values inside the bars
    for i, count in enumerate(df1['Count']):
        percentage = df1.loc[i, 'Percentage']
        plt.text(i, df1.loc[i, 'Percentage'], f'{percentage:.2f}%', ha='center', va='bottom')
        plt.text(i, percentage-2, count, ha = 'center')
 

    # Add labels and title
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(title)
    plt.show()

# %%
for i in list(data['Due Date Bucket'].unique()):
    df1 = data[data['Due Date Bucket'] == i]['# Days(RAV)'].value_counts().reset_index().rename(columns={'index': '# Days(RAV)', '# Days(RAV)': 'Count'})
    df1['# Days(RAV)'] = df1['# Days(RAV)'].astype('str')
    total = df1['Count'].sum()
    df1['Percentage'] = (df1['Count'] / total) * 100
    plot_graph(df1,i,'# Days(RAV)','Percentage')
